# %%
import pandas as pd
url="https://raw.githubusercontent.com/Edubridge-karthik/Python-Basic/main/mtcars.csv"
car_data=pd.read_csv(url)
car_data
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
car_data.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
Range=car_data[['mpg']].max()-car_data[['mpg']].min()
Range
# Out:
# mpg    23.5
# dtype: float64

# %%
car_data[['qsec']].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
car_data[['qsec']].skew()
# Out:
# qsec    0.406347
# dtype: float64

# %%
car_data[['qsec']].kurtosis()
# Out:
# qsec    0.864931
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
car_data[['mpg']].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
car_data[['mpg']].kurtosis()
# Out:
# mpg   -0.022006
# dtype: float64

# %%
car_data[['mpg']].median()
# Out:
# mpg    19.2
# dtype: float64

# %%
import statistics as stat
data=(300,38,29,28,30,28,29,27,27,28,37,40)

# %%
stat.mean(data) #Return the sample arithmetic mean of data.
# Out:
# 53.416666666666664

# %%
stat.median(data)
# Out:
# 29.0

# %%
stat.mode(data)
# Out:
# 28

# %%
car_data[['mpg']].mean()
# Out:
# mpg    20.090625
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv"
odata=pd.read_csv(url,skiprows=4)
odata.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
odata[['Gender']].mode()
# Out:
#   Gender
# 0    Men

# %%
odata[['Gender']].value_counts()
# Out:
# Gender
# Men       21721
# Women      7495
# dtype: int64

# %%
odata.describe(include='all')
# Out:
#           City       Edition     Sport Discipline           Athlete    NOC  \
# count    29216  29216.000000     29216      29216             29216  29216
# unique      22           NaN        42         56             21413    138
# top     Athens           NaN  Aquatics  Athletics  LATYNINA, Larisa    USA
# freq      2149           NaN      3828       3448                18   4335
# mean       NaN   1967.713171       NaN        NaN               NaN    NaN
# std        NaN     32.406293       NaN        NaN               NaN    NaN
# min        NaN   1896.000000       NaN        NaN               NaN    NaN
# 25%        NaN   1948.000000       NaN        NaN               NaN    NaN
# 50%        NaN   1976.000000       NaN        NaN               NaN    NaN
# 75%        NaN   1996.000000       NaN        NaN               NaN    NaN
# max        NaN   2008.000000       NaN        NaN               NaN    NaN
#
#        Gender     Event Event_gender  Medal
# ...

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
