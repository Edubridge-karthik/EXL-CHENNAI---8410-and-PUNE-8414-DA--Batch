# %% [markdown]
# # Pandas Data Analytics

# %% [markdown]
# ### Pandas Data Structures

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
# Series
s1=pd.Series([50,60,80,58,63],name='maks') #One-dimensional ndarray with axis labels (including time series).
s1
# Out:
# 0    50
# 1    60
# 2    80
# 3    58
# 4    63
# Name: maks, dtype: int64

# %%
print(type(s1))
# Out:
# <class 'pandas.core.series.Series'>

# %%
d1={'m1':50,'m2':60,'m3':80,'m4':58,'m5':63}
s2=pd.Series(d1)
s2
# Out:
# m1    50
# m2    60
# m3    80
# m4    58
# m5    63
# dtype: int64

# %%
s2.index
# Out:
# Index(['m1', 'm2', 'm3', 'm4', 'm5'], dtype='object')

# %%
s3=pd.Series((50,60,80,58,63),name='maks') #One-dimensional ndarray with axis labels (including time series).
s3
# Out:
# 0    50
# 1    60
# 2    80
# 3    58
# 4    63
# Name: maks, dtype: int64

# %%
s4=pd.Series(5) # scalar value
s4
# Out:
# 0    5
# dtype: int64

# %% [markdown]
# # Series object attribute and Method

# %%
print(dir(pd.Series))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_NAMES', '_AXIS_NUMBERS', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__',
# ...

# %% [markdown]
# ###  Attribute of Series object

# %%
d1={'m1':50,'m2':60,'m3':80,'m4':58,'m5':63}
s2=pd.Series(d1,name='marks')
s2
# Out:
# m1    50
# m2    60
# m3    80
# m4    58
# m5    63
# Name: marks, dtype: int64

# %%
s2.ndim # Number of dimensions of the underlying data
# Out:
# 1

# %%
s2.shape #Return a tuple of the shape of the underlying data.
# Out:
# (5,)

# %%
s2.size
# Out:
# 5

# %%
s2.values #Return Series as ndarray or ndarray-like depending on the dtype.
# Out:
# array([50, 60, 80, 58, 63], dtype=int64)

# %%
s2.index # return index of the s2 obj
# Out:
# Index(['m1', 'm2', 'm3', 'm4', 'm5'], dtype='object')

# %%
s2.axes
# Out:
# [Index(['m1', 'm2', 'm3', 'm4', 'm5'], dtype='object')]

# %%
s2.dtypes
# Out:
# dtype('int64')

# %%
s2.dtype
# Out:
# dtype('int64')

# %%
s2.name
# Out:
# 'marks'

# %%
s2.nbytes
# Out:
# 40

# %%
# methods of Series Object

# %%
s2.to_list() #Return a list of the values.
# Out:
# [50, 60, 80, 58, 63]

# %%
s2.head(n=3) #Return the first `n` rows.
# Out:
# m1    50
# m2    60
# m3    80
# dtype: int64

# %%
s2.tail(n=2) #Return the last `n` rows.
# Out:
# m4    58
# m5    63
# dtype: int64

# %%
#acess the data
s2
# Out:
# m1    50
# m2    60
# m3    80
# m4    58
# m5    63
# Name: marks, dtype: int64

# %%
s2['m1']
# Out:
# 50

# %%
s2[0]
# Out:
# 50

# %%
s2['m1':'m3']  # str index both start:end included
# Out:
# m1    50
# m2    60
# m3    80
# Name: marks, dtype: int64

# %%
s2[0:3]  # int index start included and End excluded
# Out:
# m1    50
# m2    60
# m3    80
# Name: marks, dtype: int64

# %%
# Recommended methods for accessing data
s2.loc['m1']   # work only str index
# Out:
# 50

# %%
s3=pd.Series((50,60,80,58,63),name='maks') #One-dimensional ndarray with axis labels (including time series).
s3
# Out:
# 0    50
# 1    60
# 2    80
# 3    58
# 4    63
# Name: maks, dtype: int64

# %%
s3.loc[1] # 1 is act as str
# Out:
# 60

# %%
s3.loc[1:3]
# Out:
# 1    60
# 2    80
# 3    58
# Name: maks, dtype: int64

# %%
#integer loc 
s3.iloc[3]
# Out:
# 58

# %%
s3.iloc[0:3]
# Out:
# 0    50
# 1    60
# 2    80
# Name: maks, dtype: int64

# %% [markdown]
# # DataFrame

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Constructing DataFrame from a dictionary.

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}
df=pd.DataFrame(d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=2, step=1), Index(['col1', 'col2'], dtype='object')]

# %%
df.values
# Out:
# array([[1, 3],
#        [2, 4]], dtype=int64)

# %%
#create DataFrame from Two Series object

# %%
data={'name':pd.Series(['raj','kiran','savitha','julie']),'marks':pd.Series([60,68,90,86])}
std_df=pd.DataFrame(data)
std_df
# Out:
#       name  marks
# 0      raj     60
# 1    kiran     68
# 2  savitha     90
# 3    julie     86

# %%
std_df.size
# Out:
# 8

# %%
std_df.shape
# Out:
# (4, 2)

# %%
std_df.ndim
# Out:
# 2

# %%
std_df.values
# Out:
# array([['raj', 60],
#        ['kiran', 68],
#        ['savitha', 90],
#        ['julie', 86]], dtype=object)

# %%
std_df.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1), Index(['name', 'marks'], dtype='object')]

# %%
std_df.index  # row index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
std_df.columns
# Out:
# Index(['name', 'marks'], dtype='object')

# %% [markdown]
# ### acessing DataFrame

# %%
data={'RegNo':pd.Series([1001,1002,1003,1004]),
    'name':pd.Series(['raj','kiran','savitha','julie']),'marks':pd.Series([60,68,90,86])}
std_df=pd.DataFrame(data)
std_df
# Out:
#    RegNo     name  marks
# 0   1001      raj     60
# 1   1002    kiran     68
# 2   1003  savitha     90
# 3   1004    julie     86

# %%
std_df
# Out:
#    RegNo     name  marks
# 0   1001      raj     60
# 1   1002    kiran     68
# 2   1003  savitha     90
# 3   1004    julie     86

# %%
#using []
std_df['name']  # slice the name columns as Series obj
# Out:
# 0        raj
# 1      kiran
# 2    savitha
# 3      julie
# Name: name, dtype: object

# %%
#using [[ ]]  # slice more than one columns as DataFrame obj
std_df[['RegNo','marks']]
# Out:
#    RegNo  marks
# 0   1001     60
# 1   1002     68
# 2   1003     90
# 3   1004     86

# %%
#using loc[]  # str fmt index  #  loc[row,column]
std_df.loc[1:3,'RegNo':'name']
# Out:
#    RegNo     name
# 1   1002    kiran
# 2   1003  savitha
# 3   1004    julie

# %%
#using .iloc[]   # df.iloc[row,column]  #int format

# %%
std_df.iloc[0:3,0:2]
# Out:
#    RegNo     name
# 0   1001      raj
# 1   1002    kiran
# 2   1003  savitha

# %% [markdown]
# # Read and Write

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# read CSV File from github url

# %%
import pandas as pd
file='https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/subset-covid-data.csv'
covid_data=pd.read_csv(file)
covid_data
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %%
file= url.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
# how to read data from Google sheet
url='https://docs.google.com/spreadsheets/d/1nl8B0femFF8Knfd-4LQ02FNoRJfg7X99OyMg-ABSHEk/edit#gid=1932088925'
file= url.replace('/edit#gid=', '/export?format=csv&gid=')
file
# Out:
# 'https://docs.google.com/spreadsheets/d/1nl8B0femFF8Knfd-4LQ02FNoRJfg7X99OyMg-ABSHEk/export?format=csv&gid=1932088925'

# %%
# read file from Google Sheet url

# %%
import pandas as pd
file='https://docs.google.com/spreadsheets/d/1nl8B0femFF8Knfd-4LQ02FNoRJfg7X99OyMg-ABSHEk/export?format=csv&gid=1932088925'
covid_df=pd.read_csv(file)
covid_df
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %%
# read file from Local drive

# %%
path=r'I:\EduBridge\Data\subset-covid-data.csv'
pd.read_csv(path)
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %%
import pandas as pd
file='https://docs.google.com/spreadsheets/d/1nl8B0femFF8Knfd-4LQ02FNoRJfg7X99OyMg-ABSHEk/export?format=csv&gid=1932088925'
covid_df=pd.read_csv(file)
covid_df
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %% [markdown]
# # Explore The Data

# %%
#data about DataFrame object

# %%
covid_df.info() #Print a concise summary of a DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       206 non-null    object
#  1   continent     206 non-null    object
#  2   date          206 non-null    object
#  3   day           206 non-null    int64
#  4   month         206 non-null    int64
#  5   year          206 non-null    int64
#  6   cases         206 non-null    int64
#  7   deaths        206 non-null    int64
#  8   country_code  202 non-null    object
#  9   population    202 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 16.2+ KB

# %%
covid_df.head(n=2)  #Return the first `n` rows. #default n=5
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0

# %%
covid_df.tail(n=10) #Return the last `n` rows.
# Out:
#                           country continent        date  day  month  year  \
# 196   United_Republic_of_Tanzania    Africa  2020-04-12   12      4  2020
# 197  United_States_Virgin_Islands   America  2020-04-12   12      4  2020
# 198      United_States_of_America   America  2020-04-12   12      4  2020
# 199                       Uruguay   America  2020-04-12   12      4  2020
# 200                    Uzbekistan      Asia  2020-04-12   12      4  2020
# 201                     Venezuela   America  2020-04-12   12      4  2020
# 202                       Vietnam      Asia  2020-04-12   12      4  2020
# 203                         Yemen      Asia  2020-04-12   12      4  2020
# 204                        Zambia    Africa  2020-04-12   12      4  2020
# 205                      Zimbabwe    Africa  2020-04-12   12      4  2020
#
#      cases  deaths country_code   population
# 196      0       0          TZA   56318348.0
# 197      1       0          VIR     106977.0
# ...

# %%
covid_df.shape
# Out:
# (206, 10)

# %%
covid_df.size
# Out:
# 2060

# %%
covid_df.ndim
# Out:
# 2

# %%
covid_df.axes
# Out:
# [RangeIndex(start=0, stop=206, step=1),
#  Index(['country', 'continent', 'date', 'day', 'month', 'year', 'cases',
#         'deaths', 'country_code', 'population'],
#        dtype='object')]

# %%
covid_df.columns
# Out:
# Index(['country', 'continent', 'date', 'day', 'month', 'year', 'cases',
#        'deaths', 'country_code', 'population'],
#       dtype='object')

# %%
# using []
covid_df['population']
# Out:
# 0      37172386.0
# 1       2866376.0
# 2      42228429.0
# 3         77006.0
# 4      30809762.0
#           ...
# 201    28870195.0
# 202    95540395.0
# 203    28498687.0
# 204    17351822.0
# 205    14439018.0
# Name: population, Length: 206, dtype: float64

# %%
#using[[ ]]
covid_df[['country','population']].head()
# Out:
#        country  population
# 0  Afghanistan  37172386.0
# 1      Albania   2866376.0
# 2      Algeria  42228429.0
# 3      Andorra     77006.0
# 4       Angola  30809762.0

# %%
# using . operator #df.column_name
covid_df.population
# Out:
# 0      37172386.0
# 1       2866376.0
# 2      42228429.0
# 3         77006.0
# 4      30809762.0
#           ...
# 201    28870195.0
# 202    95540395.0
# 203    28498687.0
# 204    17351822.0
# 205    14439018.0
# Name: population, Length: 206, dtype: float64

# %%
url='https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv'
sales_data=pd.read_csv(url)
sales_data
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
sales_data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
sales_data.Order ID
# Out:
#   Input In [116]
#     sales_data.Order ID
#                      ^
# SyntaxError: invalid syntax

# %%
sales_data.Product
# Out:
# 0                         iPhone
# 1       Lightning Charging Cable
# 2               Wired Headphones
# 3               27in FHD Monitor
# 4               Wired Headphones
#                   ...
# 9718                20in Monitor
# 9719            27in FHD Monitor
# 9720             ThinkPad Laptop
# 9721      AAA Batteries (4-pack)
# 9722                Google Phone
# Name: Product, Length: 9723, dtype: object

# %%
sales_data.columns=sales_data.columns.str.replace(' ','_')

# %%
sales_data.columns
# Out:
# Index(['Order_ID', 'Product', 'Quantity_Ordered', 'Price_Each', 'Order_Date',
#        'Purchase_Address'],
#       dtype='object')

# %%
sales_data.head()
# Out:
#   Order_ID                   Product Quantity_Ordered Price_Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order_Date                       Purchase_Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
sales_data.Order_ID
# Out:
# 0       141234
# 1       141235
# 2       141236
# 3       141237
# 4       141238
#          ...
# 9718    150497
# 9719    150498
# 9720    150499
# 9721    150500
# 9722    150501
# Name: Order_ID, Length: 9723, dtype: object

# %% [markdown]
# # read Excel file

# %% [markdown]
# ### pd.read_excel()
# - Read an Excel file into a pandas DataFrame.
# - Supports `xls`, `xlsx`, `xlsm`, `xlsb`, `odf`, `ods` and `odt` file extensions read from a local filesystem or URL. Supports an option to read a single sheet or a list of sheets.
# - strom.xlsx  data download from url:https://github.com/svkarthik86/Advanced-python/blob/main/storm.xlsx

# %%
import pandas as pd
url='https://docs.google.com/spreadsheets/d/1NngRB3i15h9o218cUumQSVNj_2U08awA/export?format=xlsx&gid=2144044941'
storm_data=pd.read_excel(url)
storm_data
# Out:
#       Season      Name Basin Type  MaxWindMPH  MinPressure  StartDate  \
# 0     1980.0       NaN   NaN   TS        35.0          NaN 1980-07-17
# 1     1980.0     ALLEN   NaN   TS       190.0        899.0 1980-07-31
# 2     1980.0    BONNIE   NaN   ET        98.0        975.0 1980-08-14
# 3     1980.0   CHARLEY   NaN   TS        81.0        989.0 1980-08-20
# 4     1980.0  DANIELLE   NaN   TS        58.0       1004.0 1980-09-04
# ...      ...       ...   ...  ...         ...          ...        ...
# 3113  2016.0     URIAH    SI   ET       127.0        925.0 2016-02-09
# 3114  2016.0    VICTOR    SP   NR        92.0        958.0 2016-01-14
# 3115  2016.0   WINSTON    SP   NR       173.0        884.0 2016-02-10
# 3116  2016.0      YALO    SP   NR        46.0        100.0 2016-02-24
# 3117  2016.0      ZENA    SP   NR        81.0        975.0 2016-04-05
#
#         EndDate Hem NS Hem EW   Lat    Lon
# 0    1980-11-18      N      W  25.7  -91.2
# ...

# %%
import pandas as pd
file='I:\EduBridge\Data\storm.xlsx'
storm_data=pd.read_excel(file,sheet_name='SubBasin_Codes')
storm_data
# Out:
#   Sub_Basin      SubBasin_Name
# 0        AS        Arabian Sea
# 1        BB      Bay of Bengal
# 2        EA  Eastern Australia
# 3        WA  Western Australia
# 4        CP    Central Pacific
# 5        CS      Caribbean Sea
# 6        GM     Gulf of Mexico
# 7        MM            Missing

# %%
import pandas as pd
file='I:\EduBridge\Data\storm.xlsx'
storm_data=pd.read_excel(file,sheet_name=[0,1,2,3,4,5,6,7])
storm_data
# Out:
# {0:       Season      Name Basin Type  MaxWindMPH  MinPressure  StartDate  \
#  0       1980       NaN   NaN   TS        35.0          NaN 1980-07-17
#  1       1980     ALLEN   NaN   TS       190.0        899.0 1980-07-31
#  2       1980    BONNIE   NaN   ET        98.0        975.0 1980-08-14
#  3       1980   CHARLEY   NaN   TS        81.0        989.0 1980-08-20
#  4       1980  DANIELLE   NaN   TS        58.0       1004.0 1980-09-04
#  ...      ...       ...   ...  ...         ...          ...        ...
#  3113    2016     URIAH    SI   ET       127.0        925.0 2016-02-09
#  3114    2016    VICTOR    SP   NR        92.0        958.0 2016-01-14
#  3115    2016   WINSTON    SP   NR       173.0        884.0 2016-02-10
#  3116    2016      YALO    SP   NR        46.0        100.0 2016-02-24
#  3117    2016      ZENA    SP   NR        81.0        975.0 2016-04-05
#
#          EndDate Hem NS Hem EW   Lat    Lon
#  0    1980-11-18      N      W  25.7  -91.2
# ...

# %%
print(type(storm_data))
# Out:
# <class 'dict'>

# %%
storm_data[7]
# Out:
#   Type           Storm_Type
# 0   TS       Tropical Storm
# 1   SS    Subtropical Storm
# 2   ET  Extratropical Storm
# 3   DS          Disturbance
# 4   NR         Not Reported

# %% [markdown]
# ## Problem -Solving using Pandas

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = {
   'name': ['James', 'Billy', 'Bob', 'Amy', 'Tom'],
   'number': ['1234', '5678', '2222', '1111', '0909']
}

# %%
import pandas as pd
people=pd.DataFrame(data,index=data['name'])
people
# Out:
#         name number
# James  James   1234
# Billy  Billy   5678
# Bob      Bob   2222
# Amy      Amy   1111
# Tom      Tom   0909

# %%
people.axes
# Out:
# [Index(['James', 'Billy', 'Bob', 'Amy', 'Tom'], dtype='object'),
#  Index(['name', 'number'], dtype='object')]

# %%
name=people.loc[input("enter name:")]
print(name)

# %%
name=input("enter name:")
print(people.loc[name])
# Out:
# enter name:Amy
# name       Amy
# number    1111
# Name: Amy, dtype: object

# %%
import pandas as pd
people=pd.DataFrame(data,index=data['name'])
people
name=people.loc[input()]
print(name)
# Out:
# Tom
# name       Tom
# number    0909
# Name: Tom, dtype: object

# %%
import pandas as pd
people=pd.DataFrame(data,index=data['name'])
people
start=int(input("enter the starting record number:"))
end=int(input("enter the ending record number:"))
name=people.iloc[start:end]
print(name)
# Out:
# enter the starting record number:0
# enter the ending record number:-1
#         name number
# James  James   1234
# Billy  Billy   5678
# Bob      Bob   2222
# Amy      Amy   1111

# %% [markdown]
# ### pd.read_json()
# - Convert a JSON string to pandas object.

# %%
import pandas as pd
url='https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/countries.json'
countries_data=pd.read_json(url)
countries_data
# Out:
#       id                       name iso3 iso2  numeric_code phone_code  \
# 0      1                Afghanistan  AFG   AF             4         93
# 1      2              Aland Islands  ALA   AX           248    +358-18
# 2      3                    Albania  ALB   AL             8        355
# 3      4                    Algeria  DZA   DZ            12        213
# 4      5             American Samoa  ASM   AS            16     +1-684
# ..   ...                        ...  ...  ...           ...        ...
# 245  243  Wallis And Futuna Islands  WLF   WF           876        681
# 246  244             Western Sahara  ESH   EH           732        212
# 247  245                      Yemen  YEM   YE           887        967
# 248  246                     Zambia  ZMB   ZM           894        260
# 249  247                   Zimbabwe  ZWE   ZW           716        263
#
#        capital currency    currency_name currency_symbol  tld  \
# ...

# %% [markdown]
# ### pd.read_html()
# - Read HTML tables into a ``list`` of ``DataFrame`` objects.

# %%
import pandas as pd
html_file='https://en.wikipedia.org/wiki/Minnesota'
page_tables=pd.read_html(html_file)
page_tables
# Out:
# [                                            Minnesota  \
#  0                                               State
#  1   .mw-parser-output .ib-settlement-cols{text-ali...
#  2   Nickname(s): Land of 10,000 Lakes;North Star S...
#  3   Motto: L'Étoile du Nord (French: The Star of t...
#  4                           Anthem: "Hail! Minnesota"
#  5   Map of the United States with Minnesota highli...
#  6                                             Country
#  7                                    Before statehood
#  8                               Admitted to the Union
#  9                                             Capital
#  10                                       Largest city
#  11                      Largest metro and urban areas
#  12                                         Government
#  13                                         • Governor
#  14                              • Lieutenant Governor
#  15                                        Legislature
# ...

# %%
page_tables[2]
# Out:
#               Location July (°F) July (°C) January (°F) January (°C)
# 0          Minneapolis     83/64     28/18         23/7       −4/−13
# 1           Saint Paul     83/63     28/17         23/6       −5/−14
# 2            Rochester     82/63     28/17         23/3       −5/−16
# 3               Duluth     76/55     24/13         19/1       −7/−17
# 4            St. Cloud     81/58     27/14        18/−1       −7/−18
# 5              Mankato     86/62     30/16         23/3       −5/−16
# 6  International Falls     77/52     25/11        15/−6       −9/−21

# %%
import pandas as pd
html_file='https://en.wikipedia.org/wiki/Minnesota'
page_Temp_table=pd.read_html(html_file,match='Average daily maximum and minimum temperatures for selected cities in Minnesota')
page_Temp_table[0]
# Out:
#               Location July (°F) July (°C) January (°F) January (°C)
# 0          Minneapolis     83/64     28/18         23/7       −4/−13
# 1           Saint Paul     83/63     28/17         23/6       −5/−14
# 2            Rochester     82/63     28/17         23/3       −5/−16
# 3               Duluth     76/55     24/13         19/1       −7/−17
# 4            St. Cloud     81/58     27/14        18/−1       −7/−18
# 5              Mankato     86/62     30/16         23/3       −5/−16
# 6  International Falls     77/52     25/11        15/−6       −9/−21

# %%
print(type(page_Temp_table))
# Out:
# <class 'list'>

# %% [markdown]
# ### pd.read_sql()
# - Read SQL query or database table into a DataFrame.

# %%
# !pip install mysql-connector-python

# %%
import pandas as pd
import mysql.connector as connection
mydb=connection.connect(host='localhost',user='root',passwd='edubridge@123',database='data_science')
#query='SELECT * FROM books;'
book_df=pd.read_sql('SELECT * FROM data_science.customer',mydb)
book_df
# Out:
# C:\Users\karthick\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    id   name          city  age
# 0   1   John      New York   35
# 1   2  David   Los Angeles   23
# 2   3  Chloe       Chicago   27
# 3   4  Emily       Houston   34
# 4   5  James  Philadelphia   31

# %%
book_df.to_json(r"I:\EduBridge\Data\books.json")

# %% [markdown]
# ## Modifying DataFrame objects
# -  to change the names of columns and add and delete columns and rows.

# %% [markdown]
# ### Renaming columns
# - The names of the columns can be changed using the rename method.
# - A dictionary is passed as an argument to this method.
# - The keys for this dictionary are the old column names, and the values are the new column names.

# %%
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
#Rename column using df.rename()
std_age.rename(columns={'class 1':'class_A','class 2':'class_B'},inplace=True) # rename in memory

# %%
std_age
# Out:
#    class_A  class_B  class 3
# 0       22       24       20
# 1       40       50       45

# %%
#over writting column using df.columns=[list of new columns name]

# %%
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
std_age.columns
# Out:
# Index(['class 1', 'class 2', 'class 3'], dtype='object')

# %%
std_age.columns=['batch-A', 'batch-B','batch-C']

# %%
std_age.columns
# Out:
# Index(['batch-A', 'batch-B', 'batch-C'], dtype='object')

# %%
std_age
# Out:
#    batch-A  batch-B  batch-C
# 0       22       24       20
# 1       40       50       45

# %%
#using df.columns.str

# %%
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
std_age.columns
# Out:
# Index(['class 1', 'class 2', 'class 3'], dtype='object')

# %%
std_age.columns.str.replace(' ','_')
# Out:
# Index(['class_1', 'class_2', 'class_3'], dtype='object')

# %%
std_age.columns=std_age.columns.str.replace(' ','_')

# %%
std_age
# Out:
#    class_1  class_2  class_3
# 0       22       24       20
# 1       40       50       45

# %% [markdown]
# ### Adding a new column to a DataFrame
# There are four ways to insert a new column in a DataFrame

# %%
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
#method1

# %%
std_age['class 4']=[45,36] ## if name column name is already present, then overwrite data, else create new column

# %%
std_age
# Out:
#    class 1  class 2  class 3  class 4
# 0       22       24       20       45
# 1       40       50       45       36

# %%
std_age['class 2']=[100,200]

# %%
std_age
# Out:
#    class 1  class 2  class 3  class 4
# 0       22      100       20       45
# 1       40      200       45       36

# %%
#method2

# %% [markdown]
# ### 2.Using the insert method

# %%
import pandas as pd
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
std_age.insert(1,'batch-B',[100,200]) #Insert column into DataFrame at specified location.
# if column name is already exist will throw error

# %%
std_age
# Out:
#    class 1  batch-B  class 2  class 3
# 0       22      100       24       20
# 1       40      200       50       45

# %% [markdown]
# ### 3.Using the loc indexer

# %%
import pandas as pd
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
import numpy as np
std_age.loc[:,'Batch-z']=np.array([23,44])  ## if Column is exist it will overwrite the data else create new column

# %%
std_age
# Out:
#    class 1  class 2  class 3  Batch-z
# 0       22       24       20       23
# 1       40       50       45       44

# %% [markdown]
# ### 4.Using the concat function

# %%
import pandas as pd
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
batch_x=pd.Series([30,45])
batch_x
# Out:
# 0    30
# 1    45
# dtype: int64

# %%
pd.concat([std_age,batch_x],axis=1).rename(columns={0:'batch_x'})
# Out:
#    class 1  class 2  class 3  batch_x
# 0       22       24       20       30
# 1       40       50       45       45

# %% [markdown]
# ## Inserting rows in a DataFrame
# - There are two methods for adding rows in a DataFrame, either by using the append method or with the concat function.

# %%
import pandas as pd
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
std_age2=pd.DataFrame({'class 1':[60],'class 2':[70],'class 3':[80]})
std_age2
# Out:
#    class 1  class 2  class 3
# 0       60       70       80

# %%
#method1

# %% [markdown]
# ### 1.Using the append method

# %%
std_age.append(std_age2) #Append rows of `other` to the end of caller, returning a new object.
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_28156\3058530448.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   std_age.append(std_age2) #Append rows of `other` to the end of caller, returning a new object.
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45
# 0       60       70       80

# %% [markdown]
# ### 2.Using the pd.concat function

# %%
import pandas as pd
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
std_age2=pd.DataFrame({'class 1':[60],'class 2':[70],'class 3':[80]})
std_age2
# Out:
#    class 1  class 2  class 3
# 0       60       70       80

# %%
new_row=pd.DataFrame([{'class 1':32,'class 2':37,'class 3':41}])
new_row
# Out:
#    class 1  class 2  class 3
# 0       32       37       41

# %%
pd.concat([std_age,new_row,std_age2],axis=0,ignore_index=True)
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45
# 2       32       37       41
# 3       60       70       80

# %% [markdown]
# ## Deleting columns from a DataFrame
# - Three methods can be used to delete a column from a DataFrame

# %%
import pandas as pd
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %% [markdown]
# ### 1.del Statement

# %%
del std_age['class 2'] # deletion occurs in original DataFrame itself.

# %%
std_age
# Out:
#    class 1  class 3
# 0       22       20
# 1       40       45

# %% [markdown]
# ### 2.Using the pop method

# %%
import pandas as pd
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
std_age.pop('class 1') #Return item and drop from frame. Raise KeyError if not found
# Out:
# 0    22
# 1    40
# Name: class 1, dtype: int64

# %%
std_age
# Out:
#    class 2  class 3
# 0       24       20
# 1       50       45

# %% [markdown]
# # 3.drop()

# %%
import pandas as pd
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
std_age.drop(['class 3','class 1'],axis=1,inplace=True) #Drop specified labels from rows or columns.

# %%
std_age
# Out:
#    class 2
# 0       24
# 1       50

# %% [markdown]
# ### Deleting a row from a DataFrame

# %% [markdown]
# # drop()

# %%
import pandas as pd
std_age=pd.DataFrame({'class 1':[22,40,60,56],'class 2':[24,50,63,23],'class 3':[20,45,22,54]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45
# 2       60       63       22
# 3       56       23       54

# %%
std_age.drop([1,3],axis=0)
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 2       60       63       22

# %% [markdown]
# # index and Multi-index, set and reset_index

# %%
import pandas as pd

# Load a sample DataFrame
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv"
olympic_df = pd.read_csv(url, index_col=['Edition','Sport'],skiprows=4)
olympic_df
# Out:
#                       City       Discipline               Athlete  NOC Gender  \
# Edition Sport
# 1896    Aquatics    Athens         Swimming         HAJOS, Alfred  HUN    Men
#         Aquatics    Athens         Swimming      HERSCHMANN, Otto  AUT    Men
#         Aquatics    Athens         Swimming     DRIVAS, Dimitrios  GRE    Men
#         Aquatics    Athens         Swimming    MALOKINIS, Ioannis  GRE    Men
#         Aquatics    Athens         Swimming    CHASAPIS, Spiridon  GRE    Men
# ...                    ...              ...                   ...  ...    ...
# 2008    Wrestling  Beijing  Wrestling Gre-R        ENGLICH, Mirko  GER    Men
#         Wrestling  Beijing  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU    Men
#         Wrestling  Beijing  Wrestling Gre-R       PATRIKEEV, Yuri  ARM    Men
#         Wrestling  Beijing  Wrestling Gre-R         LOPEZ, Mijain  CUB    Men
#         Wrestling  Beijing  Wrestling Gre-R        BAROEV, Khasan  RUS    Men
#
# ...

# %%
olympic_df.index
# Out:
# MultiIndex([(1896,  'Aquatics'),
#             (1896,  'Aquatics'),
#             (1896,  'Aquatics'),
#             (1896,  'Aquatics'),
#             (1896,  'Aquatics'),
#             (1896,  'Aquatics'),
#             (1896,  'Aquatics'),
#             (1896,  'Aquatics'),
#             (1896,  'Aquatics'),
#             (1896,  'Aquatics'),
#             ...
#             (2008, 'Wrestling'),
#             (2008, 'Wrestling'),
#             (2008, 'Wrestling'),
#             (2008, 'Wrestling'),
#             (2008, 'Wrestling'),
#             (2008, 'Wrestling'),
#             (2008, 'Wrestling'),
#             (2008, 'Wrestling'),
#             (2008, 'Wrestling'),
#             (2008, 'Wrestling')],
#            names=['Edition', 'Sport'], length=29216)

# %%
olympic_df.loc[(1896,  'Aquatics'),:]
# Out:
#                     City Discipline                Athlete  NOC Gender  \
# Edition Sport
# 1896    Aquatics  Athens   Swimming          HAJOS, Alfred  HUN    Men
#         Aquatics  Athens   Swimming       HERSCHMANN, Otto  AUT    Men
#         Aquatics  Athens   Swimming      DRIVAS, Dimitrios  GRE    Men
#         Aquatics  Athens   Swimming     MALOKINIS, Ioannis  GRE    Men
#         Aquatics  Athens   Swimming     CHASAPIS, Spiridon  GRE    Men
#         Aquatics  Athens   Swimming  CHOROPHAS, Efstathios  GRE    Men
#         Aquatics  Athens   Swimming          HAJOS, Alfred  HUN    Men
#         Aquatics  Athens   Swimming       ANDREOU, Joannis  GRE    Men
#         Aquatics  Athens   Swimming  CHOROPHAS, Efstathios  GRE    Men
#         Aquatics  Athens   Swimming          NEUMANN, Paul  AUT    Men
#         Aquatics  Athens   Swimming      PEPANOS, Antonios  GRE    Men
#
#                                        Event Event_gender   Medal
# Edition Sport
# ...

# %%
olympic_df.set_index(['Sport','City'])
# Out:
#                         Discipline               Athlete  NOC Gender  \
# Sport     City
# Aquatics  Athens          Swimming         HAJOS, Alfred  HUN    Men
#           Athens          Swimming      HERSCHMANN, Otto  AUT    Men
#           Athens          Swimming     DRIVAS, Dimitrios  GRE    Men
#           Athens          Swimming    MALOKINIS, Ioannis  GRE    Men
#           Athens          Swimming    CHASAPIS, Spiridon  GRE    Men
# ...                            ...                   ...  ...    ...
# Wrestling Beijing  Wrestling Gre-R        ENGLICH, Mirko  GER    Men
#           Beijing  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU    Men
#           Beijing  Wrestling Gre-R       PATRIKEEV, Yuri  ARM    Men
#           Beijing  Wrestling Gre-R         LOPEZ, Mijain  CUB    Men
#           Beijing  Wrestling Gre-R        BAROEV, Khasan  RUS    Men
#
#                                         Event Event_gender   Medal
# Sport     City
# ...

# %%
olympic_df.reset_index(inplace=False)
# Out:
#        Edition     City      Sport       Discipline               Athlete  \
# 0         1896   Athens   Aquatics         Swimming         HAJOS, Alfred
# 1         1896   Athens   Aquatics         Swimming      HERSCHMANN, Otto
# 2         1896   Athens   Aquatics         Swimming     DRIVAS, Dimitrios
# 3         1896   Athens   Aquatics         Swimming    MALOKINIS, Ioannis
# 4         1896   Athens   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211     2008  Beijing  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212     2008  Beijing  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213     2008  Beijing  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214     2008  Beijing  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215     2008  Beijing  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
olympic_df
# Out:
#             City      Sport       Discipline               Athlete  NOC  \
# Edition
# 1896      Athens   Aquatics         Swimming         HAJOS, Alfred  HUN
# 1896      Athens   Aquatics         Swimming      HERSCHMANN, Otto  AUT
# 1896      Athens   Aquatics         Swimming     DRIVAS, Dimitrios  GRE
# 1896      Athens   Aquatics         Swimming    MALOKINIS, Ioannis  GRE
# 1896      Athens   Aquatics         Swimming    CHASAPIS, Spiridon  GRE
# ...          ...        ...              ...                   ...  ...
# 2008     Beijing  Wrestling  Wrestling Gre-R        ENGLICH, Mirko  GER
# 2008     Beijing  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU
# 2008     Beijing  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri  ARM
# 2008     Beijing  Wrestling  Wrestling Gre-R         LOPEZ, Mijain  CUB
# 2008     Beijing  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
#
#         Gender                       Event Event_gender   Medal
# Edition
# ...

# %% [markdown]
# # Problem -Solving:

# %%
1. read csv file from url :'https://raw.githubusercontent.com/svkarthik86/Data/main/Data/ca-covid.csv'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Expected Output
# cases     32264
# deaths      574
# Name: 31.12.20, dtype: int64

# %%
import pandas as pd
url='https://raw.githubusercontent.com/svkarthik86/Data/main/Data/ca-covid.csv'
ca_covid=pd.read_csv(url)
ca_covid
# Out:
#          date       state  cases  deaths
# 0    25.01.20  California      1       0
# 1    26.01.20  California      1       0
# 2    27.01.20  California      0       0
# 3    28.01.20  California      0       0
# 4    29.01.20  California      0       0
# ..        ...         ...    ...     ...
# 337  27.12.20  California  37555      62
# 338  28.12.20  California  41720     246
# 339  29.12.20  California  34166     425
# 340  30.12.20  California  32386     437
# 341  31.12.20  California  32264     574
#
# [342 rows x 4 columns]

# %%
ca_covid.set_index('date',inplace=True)

# %%
ca_covid.drop('state',axis=1,inplace=True)

# %%
ca_covid.head(3)
# Out:
#           cases  deaths
# date
# 25.01.20      1       0
# 26.01.20      1       0
# 27.01.20      0       0

# %%
print(ca_covid.loc['31.12.20'])
# Out:
# cases     32264
# deaths      574
# Name: 31.12.20, dtype: int64

# %%
print(ca_covid.iloc[-1,:])
# Out:
# cases     32264
# deaths      574
# Name: 31.12.20, dtype: int64

# %% [markdown]
# # Pandas Data operations

# %% [markdown]
# ### 1.Reading and writing data:
# - Pandas provides functions for reading in data from various formats, such as CSV, Excel, and SQL databases, and for writing data out to these formats.

# %% [markdown]
# ### 2.Selecting and filtering data:
# - Pandas provides methods for selecting and filtering data based on certain criteria.

# %% [markdown]
# ### 3.Grouping and aggregating data:
# - Pandas provides methods for grouping and aggregating data based on certain criteria.

# %% [markdown]
# ### 4.Sorting data:
# - Pandas provides methods for sorting data based on one or more columns.

# %% [markdown]
# ### 5. Merging and joining data:
# - Pandas provides methods for merging and joining data from different sources.

# %% [markdown]
# ### 6.Reshaping data:
# - Pandas provides methods for reshaping data, such as pivoting and unstacking.

# %% [markdown]
# ### 7.Handling missing data:
# - Pandas provides methods for handling missing data, such as filling missing values or dropping rows or columns with missing values.

# %% [markdown]
# ### 8.Transforming data:
# - Pandas provides methods for transforming data, such as applying functions or scaling values.

# %% [markdown]
# ### 9.Calculating statistics:
# - Pandas provides methods for calculating various statistics, such as mean, median, standard deviation, and more.

# %% [markdown]
# ### 10.Plotting data:
# - Pandas provides methods for creating plots and charts to visualize data.

# %% [markdown]
# ### 2.Selecting and filtering data:
# - Pandas provides methods for selecting and filtering data based on certain criteria.

# %% [markdown]
# - There are several ways you can select and filter data in Pandas:
#
# #### Indexing and slicing:
# - You can use indexing and slicing to select specific rows, columns, or cells in a DataFrame.
# - For example, you can use the``` [] operator``` to select a specific column:

# %%
import pandas as pd

# Load a sample DataFrame
olympic_df = pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv",skiprows=4)
olympic_df
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
olympic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
olympic_df['Athlete']=olympic_df['Athlete'].str.upper()

# %%
#using . notation# df.column_name

# %%
olympic_df.Edition//2
# Out:
# 0         948
# 1         948
# 2         948
# 3         948
# 4         948
#          ...
# 29211    1004
# 29212    1004
# 29213    1004
# 29214    1004
# 29215    1004
# Name: Edition, Length: 29216, dtype: int64

# %%
olympic_df
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, ALFRED
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, OTTO
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, DIMITRIOS
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, IOANNIS
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, SPIRIDON
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, MIRKO
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, MINDAUGAS
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, YURI
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, MIJAIN
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, KHASAN
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
olympic_df[olympic_df.Medal.str.contains('Gold')].Athlete
# Out:
# 0              HAJOS, ALFRED
# 3         MALOKINIS, IOANNIS
# 6              HAJOS, ALFRED
# 9              NEUMANN, PAUL
# 13             BURKE, THOMAS
#                 ...
# 29199         GUENOT, STEEVE
# 29203    KVIRKELIA, MANUCHAR
# 29206       MINGUZZI, ANDREA
# 29210     KHUSHTOV, ASLANBEK
# 29214          LOPEZ, MIJAIN
# Name: Athlete, Length: 9850, dtype: object

# %%
olympic_df.axes
# Out:
# [RangeIndex(start=0, stop=29216, step=1),
#  Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#         'Event', 'Event_gender', 'Medal'],
#        dtype='object')]

# %%
#more than one column slice using [[]]
olympic_df[['Sport','Athlete']]
# Out:
#            Sport               Athlete
# 0       Aquatics         HAJOS, ALFRED
# 1       Aquatics      HERSCHMANN, OTTO
# 2       Aquatics     DRIVAS, DIMITRIOS
# 3       Aquatics    MALOKINIS, IOANNIS
# 4       Aquatics    CHASAPIS, SPIRIDON
# ...          ...                   ...
# 29211  Wrestling        ENGLICH, MIRKO
# 29212  Wrestling  MIZGAITIS, MINDAUGAS
# 29213  Wrestling       PATRIKEEV, YURI
# 29214  Wrestling         LOPEZ, MIJAIN
# 29215  Wrestling        BAROEV, KHASAN
#
# [29216 rows x 2 columns]

# %%
olympic_df[olympic_df.Medal.str.contains('Gold')][['Sport','Athlete']]
# Out:
#            Sport              Athlete
# 0       Aquatics        HAJOS, ALFRED
# 3       Aquatics   MALOKINIS, IOANNIS
# 6       Aquatics        HAJOS, ALFRED
# 9       Aquatics        NEUMANN, PAUL
# 13     Athletics        BURKE, THOMAS
# ...          ...                  ...
# 29199  Wrestling       GUENOT, STEEVE
# 29203  Wrestling  KVIRKELIA, MANUCHAR
# 29206  Wrestling     MINGUZZI, ANDREA
# 29210  Wrestling   KHUSHTOV, ASLANBEK
# 29214  Wrestling        LOPEZ, MIJAIN
#
# [9850 rows x 2 columns]

# %% [markdown]
# Pandas package Recommended Selcet and filter operation
# - loc
# - iloc

# %%
olympic_df.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
# Using loc   # str #   df.loc[row,columns]

# %%
olympic_df.loc[0:5,['Sport','Athlete']]
# Out:
#       Sport                Athlete
# 0  Aquatics          HAJOS, ALFRED
# 1  Aquatics       HERSCHMANN, OTTO
# 2  Aquatics      DRIVAS, DIMITRIOS
# 3  Aquatics     MALOKINIS, IOANNIS
# 4  Aquatics     CHASAPIS, SPIRIDON
# 5  Aquatics  CHOROPHAS, EFSTATHIOS

# %%
olympic_df.loc[0:5,'Sport':'Medal']
# Out:
#       Sport Discipline                Athlete  NOC Gender  \
# 0  Aquatics   Swimming          HAJOS, ALFRED  HUN    Men
# 1  Aquatics   Swimming       HERSCHMANN, OTTO  AUT    Men
# 2  Aquatics   Swimming      DRIVAS, DIMITRIOS  GRE    Men
# 3  Aquatics   Swimming     MALOKINIS, IOANNIS  GRE    Men
# 4  Aquatics   Swimming     CHASAPIS, SPIRIDON  GRE    Men
# 5  Aquatics   Swimming  CHOROPHAS, EFSTATHIOS  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver
# 5             1200m freestyle            M  Bronze

# %%
#using df.iloc[row,column] # integer

# %%
olympic_df.iloc[0:10:2,2:9]
# Out:
#       Sport Discipline                Athlete  NOC Gender  \
# 0  Aquatics   Swimming          HAJOS, ALFRED  HUN    Men
# 2  Aquatics   Swimming      DRIVAS, DIMITRIOS  GRE    Men
# 4  Aquatics   Swimming     CHASAPIS, SPIRIDON  GRE    Men
# 6  Aquatics   Swimming          HAJOS, ALFRED  HUN    Men
# 8  Aquatics   Swimming  CHOROPHAS, EFSTATHIOS  GRE    Men
#
#                         Event Event_gender
# 0              100m freestyle            M
# 2  100m freestyle for sailors            M
# 4  100m freestyle for sailors            M
# 6             1200m freestyle            M
# 8              400m freestyle            M

# %%
# using df.filter()

# %%
olympic_df.filter([10,20,3,4],axis=0)
# Out:
#       City  Edition      Sport Discipline             Athlete  NOC Gender  \
# 10  Athens     1896   Aquatics   Swimming   PEPANOS, ANTONIOS  GRE    Men
# 20  Athens     1896  Athletics  Athletics     GMELIN, CHARLES  GBR    Men
# 3   Athens     1896   Aquatics   Swimming  MALOKINIS, IOANNIS  GRE    Men
# 4   Athens     1896   Aquatics   Swimming  CHASAPIS, SPIRIDON  GRE    Men
#
#                          Event Event_gender   Medal
# 10              400m freestyle            M  Silver
# 20                        400m            M  Bronze
# 3   100m freestyle for sailors            M    Gold
# 4   100m freestyle for sailors            M  Silver

# %%
olympic_df.filter(['Athlete','NOC'],axis=1)
# Out:
#                     Athlete  NOC
# 0             HAJOS, ALFRED  HUN
# 1          HERSCHMANN, OTTO  AUT
# 2         DRIVAS, DIMITRIOS  GRE
# 3        MALOKINIS, IOANNIS  GRE
# 4        CHASAPIS, SPIRIDON  GRE
# ...                     ...  ...
# 29211        ENGLICH, MIRKO  GER
# 29212  MIZGAITIS, MINDAUGAS  LTU
# 29213       PATRIKEEV, YURI  ARM
# 29214         LOPEZ, MIJAIN  CUB
# 29215        BAROEV, KHASAN  RUS
#
# [29216 rows x 2 columns]

# %%
olympic_df.filter(regex='^E')  #'^E'  starting with E
# Out:
#        Edition                       Event Event_gender
# 0         1896              100m freestyle            M
# 1         1896              100m freestyle            M
# 2         1896  100m freestyle for sailors            M
# 3         1896  100m freestyle for sailors            M
# 4         1896  100m freestyle for sailors            M
# ...        ...                         ...          ...
# 29211     2008                   84 - 96kg            M
# 29212     2008                  96 - 120kg            M
# 29213     2008                  96 - 120kg            M
# 29214     2008                  96 - 120kg            M
# 29215     2008                  96 - 120kg            M
#
# [29216 rows x 3 columns]

# %%
olympic_df.filter(regex='n$')
# Out:
#        Edition
# 0         1896
# 1         1896
# 2         1896
# 3         1896
# 4         1896
# ...        ...
# 29211     2008
# 29212     2008
# 29213     2008
# 29214     2008
# 29215     2008
#
# [29216 rows x 1 columns]

# %%
seconds_series = pd.Series(pd.date_range("2000-01-01", periods=3, freq="h"))
seconds_series
# Out:
# 0   2000-01-01 00:00:00
# 1   2000-01-01 01:00:00
# 2   2000-01-01 02:00:00
# dtype: datetime64[ns]

# %%
seconds_series.dt.hour
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %% [markdown]
# ### 3.Grouping and aggregating data:
# - Pandas provides methods for grouping and aggregating data based on certain criteria.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
olympic_df.head(2)
# Out:
#      City  Edition     Sport Discipline           Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming     HAJOS, ALFRED  HUN    Men
# 1  Athens     1896  Aquatics   Swimming  HERSCHMANN, OTTO  AUT    Men
#
#             Event Event_gender   Medal
# 0  100m freestyle            M    Gold
# 1  100m freestyle            M  Silver

# %%
go=olympic_df.groupby(by='Medal')#Group DataFrame using a mapper or by a Series of columns.

# %%
list(go)[2][1]
# Out:
#           City  Edition      Sport       Discipline             Athlete  NOC  \
# 1       Athens     1896   Aquatics         Swimming    HERSCHMANN, OTTO  AUT
# 4       Athens     1896   Aquatics         Swimming  CHASAPIS, SPIRIDON  GRE
# 7       Athens     1896   Aquatics         Swimming    ANDREOU, JOANNIS  GRE
# 10      Athens     1896   Aquatics         Swimming   PEPANOS, ANTONIOS  GRE
# 14      Athens     1896  Athletics        Athletics      HOFMANN, FRITZ  GER
# ...        ...      ...        ...              ...                 ...  ...
# 29200  Beijing     2008  Wrestling  Wrestling Gre-R  BEGALIEV, KANATBEK  KGZ
# 29204  Beijing     2008  Wrestling  Wrestling Gre-R    CHANG, YONGXIANG  CHN
# 29207  Beijing     2008  Wrestling  Wrestling Gre-R       FODOR, ZOLTAN  HUN
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R      ENGLICH, MIRKO  GER
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R      BAROEV, KHASAN  RUS
#
# ...

# %%
for key,df in go:
    print(key,df)
# Out:
# Bronze           City  Edition      Sport       Discipline                Athlete  \
# 2       Athens     1896   Aquatics         Swimming      DRIVAS, DIMITRIOS
# 5       Athens     1896   Aquatics         Swimming  CHOROPHAS, EFSTATHIOS
# 8       Athens     1896   Aquatics         Swimming  CHOROPHAS, EFSTATHIOS
# 11      Athens     1896  Athletics        Athletics          LANE, FRANCIS
# 12      Athens     1896  Athletics        Athletics       SZOKOLYI, ALAJOS
# ...        ...      ...        ...              ...                    ...
# 29205  Beijing     2008  Wrestling  Wrestling Gre-R          AVLUCA, NAZMI
# 29208  Beijing     2008  Wrestling  Wrestling Gre-R        MAMBETOV, ASSET
# 29209  Beijing     2008  Wrestling  Wrestling Gre-R          WHEELER, ADAM
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R   MIZGAITIS, MINDAUGAS
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R        PATRIKEEV, YURI
#
# ...

# %%
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/subset-covid-data.csv"
covid_data=pd.read_csv(url)
covid_data.head(3)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0

# %%
len(covid_data.country.unique())
# Out:
# 206

# %%
covid_data.continent.unique() #Return unique values of Series object.
# Out:
# array(['Asia', 'Europe', 'Africa', 'America', 'Oceania', 'Other'],
#       dtype=object)

# %%
covid_go=covid_data.groupby(['continent','country'])

# %%
for key,df in covid_go:
    print(key)
# Out:
# ('Africa', 'Algeria')
# ('Africa', 'Angola')
# ('Africa', 'Benin')
# ('Africa', 'Botswana')
# ('Africa', 'Burkina_Faso')
# ('Africa', 'Burundi')
# ('Africa', 'Cameroon')
# ('Africa', 'Cape_Verde')
# ('Africa', 'Central_African_Republic')
# ('Africa', 'Chad')
# ('Africa', 'Congo')
# ('Africa', 'Cote_dIvoire')
# ('Africa', 'Democratic_Republic_of_the_Congo')
# ('Africa', 'Djibouti')
# ('Africa', 'Egypt')
# ('Africa', 'Equatorial_Guinea')
# ('Africa', 'Eritrea')
# ('Africa', 'Eswatini')
# ('Africa', 'Ethiopia')
# ('Africa', 'Gabon')
# ('Africa', 'Gambia')
# ('Africa', 'Ghana')
# ('Africa', 'Guinea')
# ('Africa', 'Guinea_Bissau')
# ('Africa', 'Kenya')
# ('Africa', 'Liberia')
# ('Africa', 'Libya')
# ('Africa', 'Madagascar')
# ('Africa', 'Malawi')
# ('Africa', 'Mali')
# ('Africa', 'Mauritania')
# ('Africa', 'Mauritius')
# ('Africa', 'Morocco')
# ('Africa', 'Mozambique')
# ('Africa', 'Namibia')
# ('Africa', 'Niger')
# ('Africa', 'Nigeria')
# ('Africa', 'Rwanda')
# ...

# %%
covid_go=covid_data.groupby(['continent'])

# %%
for key,df in covid_go:
    print(key)
# Out:
# Africa
# America
# Asia
# Europe
# Oceania
# Other

# %%
attribute and methods of Groupby object

# %%
print(dir(covid_go))
# Out:
# ['__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_accessors', '_agg_examples_doc', '_agg_general', '_agg_py_fallback', '_aggregate_frame', '_aggregate_item_by_item', '_aggregate_with_numba', '_apply_allowlist', '_apply_filter', '_apply_to_column_groupbys', '_ascending_count', '_bool_agg', '_cache', '_can_use_transform_fast', '_choose_path', '_concat_objects', '_constructor', '_cumcount_array', '_cython_agg_general', '_cython_transform', '_define_paths', '_descending_count', '_dir_additions', '_dir_deletions', '_fill', '_get_cythonized_result', '_get_dat
# ...

# %%
covid_go.groups
# Out:
# {'Africa': [2, 4, 20, 26, 31, 32, 34, 36, 39, 40, 44, 46, 52, 54, 58, 60, 61, 63, 64, 71, 72, 75, 83, 84, 104, 111, 112, 116, 117, 120, 122, 123, 130, 131, 133, 139, 140, 158, 163, 165, 167, 168, 173, 174, 176, 179, 187, 189, 192, 196, 204, 205], 'America': [5, 6, 7, 9, 13, 16, 19, 21, 23, 24, 27, 28, 35, 38, 41, 43, 45, 48, 49, 55, 56, 57, 59, 65, 78, 79, 81, 85, 86, 88, 99, 124, 129, 138, 147, 149, 150, 154, 159, 160, 161, 170, 180, 188, 191, 197, 198, 199, 201], 'Asia': [0, 14, 15, 22, 29, 33, 42, 91, 92, 93, 94, 97, 100, 102, 103, 106, 107, 108, 110, 118, 119, 127, 132, 134, 144, 145, 146, 151, 155, 164, 169, 175, 178, 183, 184, 185, 186, 190, 194, 200, 202, 203], 'Europe': [1, 3, 8, 11, 12, 17, 18, 25, 30, 47, 50, 51, 53, 62, 66, 68, 69, 73, 74, 76, 77, 82, 87, 89, 90, 95, 96, 98, 101, 105, 109, 113, 114, 115, 121, 125, 126, 128, 135, 141, 143, 152, 153, 156, 157, 162, 166, 171, 172, 177, 181, 182, 193, 195], 'Oceania': [10, 67, 70, 80, 136, 137, 142, 148], 'Other': [37]}

# %%
covid_go.groups.keys()
# Out:
# dict_keys(['Africa', 'America', 'Asia', 'Europe', 'Oceania', 'Other'])

# %%
covid_go.ngroups
# Out:
# 6

# %%
covid_go.size() #Compute group sizes.
# Out:
# continent
# Africa     52
# America    49
# Asia       42
# Europe     54
# Oceania     8
# Other       1
# dtype: int64

# %%
covid_go.get_group('Africa')
# Out:
#                               country continent        date  day  month  year  \
# 2                             Algeria    Africa  2020-04-12   12      4  2020
# 4                              Angola    Africa  2020-04-12   12      4  2020
# 20                              Benin    Africa  2020-04-12   12      4  2020
# 26                           Botswana    Africa  2020-04-12   12      4  2020
# 31                       Burkina_Faso    Africa  2020-04-12   12      4  2020
# 32                            Burundi    Africa  2020-04-12   12      4  2020
# 34                           Cameroon    Africa  2020-04-12   12      4  2020
# 36                         Cape_Verde    Africa  2020-04-12   12      4  2020
# 39           Central_African_Republic    Africa  2020-04-12   12      4  2020
# 40                               Chad    Africa  2020-04-12   12      4  2020
# 44                              Congo    Africa  2020-04-12   12      4  2020
# ...

# %%
covid_go.agg({'cases':[min,max,'count']})
# Out:
#           cases
#             min    max count
# continent
# Africa        0    145    52
# America       0  28391    49
# Asia          0   5138    42
# Europe        0   8719    54
# Oceania       0     51     8
# Other         0      0     1

# %%
import numpy as np

# %%
covid_data.groupby(['continent']).agg([min,max,'count',np.mean])[['cases','deaths']]
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_16900\1555380923.py:1: FutureWarning: ['country', 'date', 'country_code'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   covid_data.groupby(['continent']).agg([min,max,'count',np.mean])[['cases','deaths']]
#           cases                          deaths
#             min    max count        mean    min   max count       mean
# continent
# Africa        0    145    52   13.730769      0    19    52   1.000000
# America       0  28391    49  684.061224      0  1831    49  43.081633
# Asia          0   5138    42  309.023810      0   125    42   9.119048
# Europe        0   8719    54  632.240741      0   839    54  66.129630
# Oceania       0     51     8    8.500000      0     3     8   0.500000
# Other         0      0     1    0.000000      0     0     1   0.000000

# %%
covid_data.groupby(['continent']).agg({'cases':[min,max,'count'],'deaths':[np.mean,np.var,np.std]})
# Out:
#           cases                  deaths
#             min    max count       mean           var         std
# continent
# Africa        0    145    52   1.000000      9.411765    3.067860
# America       0  28391    49  43.081633  68250.201531  261.247395
# Asia          0   5138    42   9.119048    614.009872   24.779223
# Europe        0   8719    54  66.129630  33339.284766  182.590484
# Oceania       0     51     8   0.500000      1.142857    1.069045
# Other         0      0     1   0.000000           NaN         NaN

# %% [markdown]
# ### 4.Sorting data:
# - Pandas provides methods for sorting data based on one or more columns.
# - df.sort_values()

# %%
covid_data.head(2)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0

# %%
covid_data.sort_values(by=['continent','population'], ascending=False)  #Sort by the values along either axis.
# Out:
#                                         country continent        date  day  \
# 37   Cases_on_an_international_conveyance_Japan     Other  2020-01-18   18
# 10                                    Australia   Oceania  2020-04-12   12
# 148                            Papua_New_Guinea   Oceania  2020-04-12   12
# 137                                 New_Zealand   Oceania  2020-04-12   12
# 67                                         Fiji   Oceania  2020-04-12   12
# ..                                          ...       ...         ...  ...
# 54                                     Djibouti    Africa  2020-04-12   12
# 36                                   Cape_Verde    Africa  2020-04-12   12
# 163                       Sao_Tome_and_Principe    Africa  2020-04-12   12
# 167                                  Seychelles    Africa  2020-04-12   12
# 61                                      Eritrea    Africa  2020-04-12   12
#
#      month  year  cases  deaths country_code  population
# ...

# %% [markdown]
# ### 5. Merging and joining data:
# - Pandas provides methods for merging and joining data from different sources.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Join method – index to index
# - The join method aligns two Pandas objects based on common index values.
# - That is,it looks for matching index values in both objects and then align them vertically.
# - The default type of join for this method is a left join.
# - Let us consider the following example where we join two objects.

# %%
periodic_table=pd.DataFrame({'Atomic Number':[1,2,3,4,5],'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron'],'Symbol':['H','He',
'Li','Be','B']})
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %%
periodic_table_extended=pd.DataFrame({'Atomic Number':[8,9,10],'Element':['Oxygen','Fluorine','Neon'],'Symbol':['O','F','Ne']},index=[1,20,30])
periodic_table_extended
# Out:
#     Atomic Number   Element Symbol
# 1               8    Oxygen      O
# 20              9  Fluorine      F
# 30             10      Neon     Ne

# %%
periodic_table.join(periodic_table_extended,lsuffix='_left',rsuffix='_right',how= 'left') #Join columns of another DataFrame.
# Out:
#    Atomic Number_left Element_left Symbol_left  Atomic Number_right  \
# 0                   1     Hydrogen           H                  NaN
# 1                   2       Helium          He                  8.0
# 2                   3      Lithium          Li                  NaN
# 3                   4    Beryllium          Be                  NaN
# 4                   5        Boron           B                  NaN
#
#   Element_right Symbol_right
# 0           NaN          NaN
# 1        Oxygen            O
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN

# %%
periodic_table.join(periodic_table_extended,lsuffix='_left',rsuffix='_right',how= 'right')
# Out:
#     Atomic Number_left Element_left Symbol_left  Atomic Number_right  \
# 1                  2.0       Helium          He                    8
# 20                 NaN          NaN         NaN                    9
# 30                 NaN          NaN         NaN                   10
#
#    Element_right Symbol_right
# 1         Oxygen            O
# 20      Fluorine            F
# 30          Neon           Ne

# %%
periodic_table.join(periodic_table_extended,lsuffix='_left',rsuffix='_right',how= 'inner')
# Out:
#    Atomic Number_left Element_left Symbol_left  Atomic Number_right  \
# 1                   2       Helium          He                    8
#
#   Element_right Symbol_right
# 1        Oxygen            O

# %%
periodic_table.join(periodic_table_extended,lsuffix='_left',rsuffix='_right',how= 'outer')
# Out:
#     Atomic Number_left Element_left Symbol_left  Atomic Number_right  \
# 0                  1.0     Hydrogen           H                  NaN
# 1                  2.0       Helium          He                  8.0
# 2                  3.0      Lithium          Li                  NaN
# 3                  4.0    Beryllium          Be                  NaN
# 4                  5.0        Boron           B                  NaN
# 20                 NaN          NaN         NaN                  9.0
# 30                 NaN          NaN         NaN                 10.0
#
#    Element_right Symbol_right
# 0            NaN          NaN
# 1         Oxygen            O
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# 20      Fluorine            F
# 30          Neon           Ne

# %%
periodic_table.join(periodic_table_extended,lsuffix='_left',rsuffix='_right',how= 'cross')
# Out:
#     Atomic Number_left Element_left Symbol_left  Atomic Number_right  \
# 0                    1     Hydrogen           H                    8
# 1                    1     Hydrogen           H                    9
# 2                    1     Hydrogen           H                   10
# 3                    2       Helium          He                    8
# 4                    2       Helium          He                    9
# 5                    2       Helium          He                   10
# 6                    3      Lithium          Li                    8
# 7                    3      Lithium          Li                    9
# 8                    3      Lithium          Li                   10
# 9                    4    Beryllium          Be                    8
# 10                   4    Beryllium          Be                    9
# 11                   4    Beryllium          Be                   10
# 12                   5        Boron           B                    8
# ...

# %% [markdown]
# ### Merge method – SQL type join based on common columns
# - Like the join method, the merge method is also used to join objects horizontally.
# - It is used when we join two DataFrame objects with a common column name.
# - The maindifference between the join and merge methods is that
# - the join method combines the objects based on common index values, while the merge method combines the objects based on common column names.
# - Another difference is that the default join type in the merge method is an inner join,
# - while the join method performs a left join of the objects by default.
# - Let us look at how the merge method works with an example. The two DataFrame objects defined here have a column name that is common – Atomic Number.
# - This is a scenario where we can apply the merge method.

# %%
periodic_table=pd.DataFrame({'Atomic Number':[1,2,3,4,5],'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron'],
                             'Symbol':['H','He','Li','Be','B']})
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %%
periodic_table_extended=pd.DataFrame({'Number':[1,2,3],'Natural':'Yes'})
periodic_table_extended
# Out:
#    Number Natural
# 0       1     Yes
# 1       2     Yes
# 2       3     Yes

# %%
#Merge DataFrame or named Series objects with a database-style join.

# %%
periodic_table.merge(periodic_table_extended,how='inner',left_on='Atomic Number', right_on='Number')
# Out:
#    Atomic Number   Element Symbol  Number Natural
# 0              1  Hydrogen      H       1     Yes
# 1              2    Helium     He       2     Yes
# 2              3   Lithium     Li       3     Yes

# %%
periodic_table.merge(periodic_table_extended,how='outer',left_on='Atomic Number', right_on='Number')
# Out:
#    Atomic Number    Element Symbol  Number Natural
# 0              1   Hydrogen      H     1.0     Yes
# 1              2     Helium     He     2.0     Yes
# 2              3    Lithium     Li     3.0     Yes
# 3              4  Beryllium     Be     NaN     NaN
# 4              5      Boron      B     NaN     NaN

# %%
periodic_table.merge(periodic_table_extended,how='left',left_on='Atomic Number', right_on='Number')
# Out:
#    Atomic Number    Element Symbol  Number Natural
# 0              1   Hydrogen      H     1.0     Yes
# 1              2     Helium     He     2.0     Yes
# 2              3    Lithium     Li     3.0     Yes
# 3              4  Beryllium     Be     NaN     NaN
# 4              5      Boron      B     NaN     NaN

# %%
periodic_table.merge(periodic_table_extended,how='right',left_on='Atomic Number', right_on='Number')
# Out:
#    Atomic Number   Element Symbol  Number Natural
# 0              1  Hydrogen      H       1     Yes
# 1              2    Helium     He       2     Yes
# 2              3   Lithium     Li       3     Yes

# %% [markdown]
# # Exercise problems:

# %% [raw]
# Exercise problems:
#
# read the data from given url to DataFrame as sales_data
# https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv
#
# Q1.Rename The column name with valid format:
#     oldname:Order ID,Product,Quantity Ordered,Price Each,Order Date,Purchase Address
#     newname:Order_ID,Product,Quantity_Ordered,Price_Each,Order_Date,Purchase_Address
#
# Q2.Delete the column Purchase_Address
# Q3.insert new column as order_price
# compute order_price =Price_Each*Quantity_Ordered
#
# Q4.insert new row data as  at last
# 100001,OnePhone,1,600, 01/22/19 21:25,600
#
# Q5.Gruopby Product and apply the aggregate function min,max,mean on order_price

# %%
url='https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv'
sales_data=pd.read_csv(url)
sales_data
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity Ordered  9697 non-null   object
#  3   Price Each        9697 non-null   object
#  4   Order Date        9697 non-null   object
#  5   Purchase Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %% [markdown]
# Q1.Rename The column name with valid format:
#     oldname:Order ID,Product,Quantity Ordered,Price Each,Order Date,Purchase Address
#     newname:Order_ID,Product,Quantity_Ordered,Price_Each,Order_Date,Purchase_Address

# %%
sales_data.columns=sales_data.columns.str.replace(' ',"_")

# %%
sales_data.head(2)
# Out:
#   Order_ID                   Product Quantity_Ordered Price_Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
#
#        Order_Date                  Purchase_Address
# 0  01/22/19 21:25   944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15  185 Maple St, Portland, OR 97035

# %% [markdown]
# Q2.Delete the column Purchase_Address

# %%
sales_data.drop('Purchase_Address',axis=1, inplace=True)

# %%
sales_data.head(3)
# Out:
#   Order_ID                   Product Quantity_Ordered Price_Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
#
#        Order_Date
# 0  01/22/19 21:25
# 1  01/28/19 14:15
# 2  01/17/19 13:33

# %% [markdown]
# Q3.insert new column as order_price
# compute order_price =Price_Each*Quantity_Ordered

# %%
sales_data['order_price']=sales_data.Price_Each.astype('float') *sales_data.Quantity_Ordered.astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [105], in <cell line: 1>()
# ----> 1 sales_data['order_price']=sales_data.Price_Each.astype('float') *sales_data.Quantity_Ordered.astype('int')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
Find the ValueError: could not convert string to float: 'Price Each'

# %%
sales_data[sales_data.Price_Each=='Price Each']
# Out:
#       Order_ID  Product  Quantity_Ordered  Price_Each  Order_Date
# 1073  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1102  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1194  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1897  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2463  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3115  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3247  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3612  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3623  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 4901  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 5593  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 6506  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 7544  Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...

# %%
len(sales_data[sales_data.Price_Each=='Price Each'])
# Out:
# 16

# %%
sales_data.iloc[1070:1080,:]
# Out:
#       Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 1070    142257                    iPhone                 1         700
# 1071    142258  Lightning Charging Cable                 1       14.95
# 1072    142259                  LG Dryer                 1       600.0
# 1073  Order ID                   Product  Quantity Ordered  Price Each
# 1074    142260    AAA Batteries (4-pack)                 2        2.99
# 1075    142261                    iPhone                 1         700
# 1076    142261          Wired Headphones                 1       11.99
# 1077    142262      USB-C Charging Cable                 1       11.95
# 1078    142263          Wired Headphones                 1       11.99
# 1079    142264                  LG Dryer                 1       600.0
#
#           Order_Date
# 1070  01/01/19 12:16
# 1071  01/05/19 23:40
# 1072  01/20/19 08:03
# 1073      Order Date
# 1074  01/19/19 19:15
# 1075  01/23/19 08:47
# 1076  01/23/19 08:47
# ...

# %%
#Using ~ to clean unwanted data

# %%
sales_data=sales_data[~(sales_data.Price_Each=='Price Each')]

# %%
sales_data.iloc[1070:1080,:]
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 1070   142257                    iPhone                1        700
# 1071   142258  Lightning Charging Cable                1      14.95
# 1072   142259                  LG Dryer                1      600.0
# 1074   142260    AAA Batteries (4-pack)                2       2.99
# 1075   142261                    iPhone                1        700
# 1076   142261          Wired Headphones                1      11.99
# 1077   142262      USB-C Charging Cable                1      11.95
# 1078   142263          Wired Headphones                1      11.99
# 1079   142264                  LG Dryer                1      600.0
# 1080   142265          Wired Headphones                2      11.99
#
#           Order_Date
# 1070  01/01/19 12:16
# 1071  01/05/19 23:40
# 1072  01/20/19 08:03
# 1074  01/19/19 19:15
# 1075  01/23/19 08:47
# 1076  01/23/19 08:47
# 1077  01/09/19 18:56
# 1078  01/06/19 23:07
# ...

# %%
sales_data['order_price']=sales_data.Price_Each.astype('float') *sales_data.Quantity_Ordered.astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [116], in <cell line: 1>()
# ----> 1 sales_data['order_price']=sales_data.Price_Each.astype('float') *sales_data.Quantity_Ordered.astype('int')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %% [markdown]
# ValueError: cannot convert float NaN to integer

# %%
#finding NAN

# %%
sales_data.isna().sum()#.sum()
# Out:
# Order_ID            26
# Product             26
# Quantity_Ordered    26
# Price_Each          26
# Order_Date          26
# dtype: int64

# %%
sales_data.isna().sum().sum()# total NAN values present in data set
# Out:
# 130

# %%
sales_data[sales_data.isna().any(axis=1)]
# Out:
#      Order_ID Product Quantity_Ordered Price_Each Order_Date
# 664       NaN     NaN              NaN        NaN        NaN
# 678       NaN     NaN              NaN        NaN        NaN
# 797       NaN     NaN              NaN        NaN        NaN
# 876       NaN     NaN              NaN        NaN        NaN
# 1299      NaN     NaN              NaN        NaN        NaN
# 1491      NaN     NaN              NaN        NaN        NaN
# 1699      NaN     NaN              NaN        NaN        NaN
# 3047      NaN     NaN              NaN        NaN        NaN
# 3082      NaN     NaN              NaN        NaN        NaN
# 3584      NaN     NaN              NaN        NaN        NaN
# 3659      NaN     NaN              NaN        NaN        NaN
# 4689      NaN     NaN              NaN        NaN        NaN
# 5061      NaN     NaN              NaN        NaN        NaN
# 5570      NaN     NaN              NaN        NaN        NaN
# ...

# %%
len(sales_data[sales_data.isna().any(axis=1)])
# Out:
# 26

# %%
sales_data.iloc[660:670,:]
# Out:
#     Order_ID                   Product Quantity_Ordered Price_Each  \
# 660   141877      USB-C Charging Cable                1      11.95
# 661   141878  Apple Airpods Headphones                1        150
# 662   141879     AA Batteries (4-pack)                1       3.84
# 663   141880    AAA Batteries (4-pack)                2       2.99
# 664      NaN                       NaN              NaN        NaN
# 665   141881    AAA Batteries (4-pack)                7       2.99
# 666   141882     AA Batteries (4-pack)                1       3.84
# 667   141883     AA Batteries (4-pack)                1       3.84
# 668   141884              Google Phone                1        600
# 669   141885          Wired Headphones                1      11.99
#
#          Order_Date
# 660  01/01/19 15:49
# 661  01/17/19 16:06
# 662  01/20/19 20:03
# 663  01/31/19 01:21
# 664             NaN
# 665  01/19/19 16:36
# 666  01/08/19 22:08
# 667  01/15/19 21:42
# 668  01/08/19 10:18
# ...

# %%
sales_data.shape
# Out:
# (9707, 5)

# %%
sales_data[~(sales_data.isna().any(axis=1))]  #mehod1 to remove NAN
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order_Date
# 0     01/22/19 21:25
# 1     01/28/19 14:15
# 2     01/17/19 13:33
# 3     01/05/19 20:33
# 4     01/25/19 11:59
# ...

# %%
# method 2 using dropna()

# %%
sales_data.dropna(how='all',axis=0,inplace=True)
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_28156\3034563502.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data.dropna(how='all',axis=0,inplace=True)

# %%
sales_data['order_price']=sales_data.Price_Each.astype('float') *sales_data.Quantity_Ordered.astype('int')
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_28156\1814676089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data['order_price']=sales_data.Price_Each.astype('float') *sales_data.Quantity_Ordered.astype('int')

# %%
sales_data
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order_Date  order_price
# 0     01/22/19 21:25       700.00
# 1     01/28/19 14:15        14.95
# 2     01/17/19 13:33        23.98
# ...

# %%
sales_data.columns
# Out:
# Index(['Order_ID', 'Product', 'Quantity_Ordered', 'Price_Each', 'Order_Date',
#        'order_price'],
#       dtype='object')

# %% [markdown]
# Q4.insert new row data as  at last
# 100001,OnePhone,1,600, 01/22/19 21:25,600

# %%
newdf=pd.DataFrame(data={'Order_ID':[100001], 'Product':['OnePhone'], 'Quantity_Ordered':[1], 'Price_Each':[600], 'Order_Date':['01/22/19 21:25'],
       'order_price':[600]})

# %%
newdf
# Out:
#    Order_ID   Product  Quantity_Ordered  Price_Each      Order_Date  \
# 0    100001  OnePhone                 1         600  01/22/19 21:25
#
#    order_price
# 0          600

# %%
pd.concat([sales_data,newdf],axis=0,ignore_index=True)
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9677   150498          27in FHD Monitor                1     149.99
# 9678   150499           ThinkPad Laptop                1     999.99
# 9679   150500    AAA Batteries (4-pack)                2       2.99
# 9680   150501              Google Phone                1        600
# 9681   100001                  OnePhone                1        600
#
#           Order_Date  order_price
# 0     01/22/19 21:25       700.00
# 1     01/28/19 14:15        14.95
# 2     01/17/19 13:33        23.98
# ...

# %% [markdown]
# Q5.Gruopby Product and apply the aggregate function min,max,mean on order_price

# %%
sales_data.groupby('Product').agg({'order_price':[min,max,'mean']})
# Out:
#                            order_price
#                                    min      max         mean
# Product
# 20in Monitor                    109.99   219.98   111.022770
# 27in 4K Gaming Monitor          389.99   389.99   389.990000
# 27in FHD Monitor                149.99   299.98   150.348828
# 34in Ultrawide Monitor          379.99   759.98   381.204026
# AA Batteries (4-pack)             3.84    19.20     5.266603
# AAA Batteries (4-pack)            2.99    20.93     4.410388
# Apple Airpods Headphones        150.00   300.00   150.927070
# Bose SoundSport Headphones       99.99   199.98   100.447271
# Flatscreen TV                   300.00   300.00   300.000000
# Google Phone                    600.00  1200.00   601.892744
# LG Dryer                        600.00   600.00   600.000000
# LG Washing Machine              600.00   600.00   600.000000
# Lightning Charging Cable         14.95    44.85    16.111845
# Macbook Pro Laptop             1700.00  1700.00  1700.000000
# ...

# %% [markdown]
# ### 7.Handling missing data:
# - Pandas provides methods for handling missing data, such as filling missing values or dropping rows or columns with missing values.

# %% [markdown]
# # Dealing with missing data
# - Missing data in Pandas is represented by the value NaN (Not a Number), denoted as the keyword np.nan.
# - We can use the isna or isnull method for finding null values.
# - Both methods return a True (for a missing value) or False (for all other values) Boolean value for each object in the Series or DataFrame.

# %%
#isna or isnull
import numpy as np
import pandas as pd
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/subset-covid-data.csv"
covid_data=pd.read_csv(url)
covid_data.head(3)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0

# %%
covid_data.isna().sum()
# Out:
# country         0
# continent       0
# date            0
# day             0
# month           0
# year            0
# cases           0
# deaths          0
# country_code    4
# population      4
# dtype: int64

# %%
 covid_data.isnull().sum()
# Out:
# country         0
# continent       0
# date            0
# day             0
# month           0
# year            0
# cases           0
# deaths          0
# country_code    4
# population      4
# dtype: int64

# %%
#neagtive ?

# %%
covid_data.notnull().sum()
# Out:
# country         206
# continent       206
# date            206
# day             206
# month           206
# year            206
# cases           206
# deaths          206
# country_code    202
# population      202
# dtype: int64

# %%
covid_data.notna().sum()
# Out:
# country         206
# continent       206
# date            206
# day             206
# month           206
# year            206
# cases           206
# deaths          206
# country_code    202
# population      202
# dtype: int64

# %%
#find The NaN record
covid_data[covid_data.isna().any(axis=1)]
# Out:
#                                        country continent        date  day  \
# 5                                     Anguilla   America  2020-04-12   12
# 24           Bonaire, Saint Eustatius and Saba   America  2020-04-12   12
# 37  Cases_on_an_international_conveyance_Japan     Other  2020-01-18   18
# 61                                     Eritrea    Africa  2020-04-12   12
# 65                 Falkland_Islands_(Malvinas)   America  2020-04-12   12
#
#     month  year  cases  deaths country_code  population
# 5       4  2020      0       0          NaN         NaN
# 24      4  2020      0       0          NaN         NaN
# 37      1  2020      0       0          NaN      3000.0
# 61      4  2020      0       0          ERI         NaN
# 65      4  2020      0       0          NaN         NaN

# %% [markdown]
# - We have two options for dealing with this missing data
# - either get rid of these values (drop them), or
# - substitute these values with a suitable measure (like the mean,median, or mode) that can be used as an approximation for the missing value.

# %% [markdown]
# ### Dropping the missing data
# - The dropna method removes all the missing values in a DataFrame or Series.

# %%
dropnadf=covid_data.dropna(how='any')

# %%
dropnadf.head(8)
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 0          Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1              Albania    Europe  2020-04-12   12      4  2020     17       0
# 2              Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3              Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
# 8              Armenia    Europe  2020-04-12   12      4  2020     30       2
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0
# 3          AND     77006.0
# 4          AGO  30809762.0
# 6          ATG     96286.0
# 7          ARG  44494502.0
# 8          ARM   2951776.0

# %%
dropnadf.isna().sum()
# Out:
# country         0
# continent       0
# date            0
# day             0
# month           0
# year            0
# cases           0
# deaths          0
# country_code    0
# population      0
# dtype: int64

# %% [markdown]
# ### Imputation
# - Imputation is the process of replacing missing values.
# - In Pandas, there is an option to substitute the missing values with measures of central tendencies like the mean, median,or mode, using the fillna method. You can also fill the missing values with a fixed or constant value like 0.
# - We can use the forward fill technique to fill the missing value with the value just before it,or the backward fill technique to substitute the null value with the value just after it.

# %% [markdown]
# ### forward fill - pad / ffill
# - Let us substitute the NaN value for the country "Anguilla" with the values preceding it (in the previous row), using the forward fill technique (ffill), as shown in the following.

# %%
covid_data.loc[4:7,:] #view some nan values
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN         NaN
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
covid_data.fillna(method='ffill',inplace=False).loc[4:7,:] #Fill NA/NaN values using the specified method.
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          AGO  30809762.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
#backfill

# %%
covid_data.loc[4:7,:] #view some nan values
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN         NaN
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
covid_data.fillna(method='backfill',inplace=False).loc[4:7,:]
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          ATG     96286.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %% [markdown]
# ### fill with static method
# - A standard method for imputation of missing values is to substitute the null values with the mean value of the other valid observations.
# - The fillna method can be used for this purpose, as well.
# - Here, we are substituting the missing value in each column with the mean of the other two values in the column.

# %%
covid_data.median(numeric_only=True)
# Out:
# day                12.0
# month               4.0
# year             2020.0
# cases              11.5
# deaths              0.0
# population    7042861.5
# dtype: float64

# %%
covid_data.loc[4:7,:]
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN         NaN
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
covid_data.fillna(covid_data.median(numeric_only=True),inplace=False).loc[4:7,:]
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN   7042861.5
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
#constant value

# %%
covid_data.fillna(100,inplace=False).loc[4:7,:]
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          100       100.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %% [markdown]
# ### using Interpolation method
# - Interpolation is another technique for estimating missing values in numeric columns, with the most straightforward interpolation technique being the linear interpolation method.
# - In linear interpolation, the equation of a straight line is used to estimate unknown values from known values. If there are two points, (x0, y0) and (x1,y1), then an unknown point (x,y) can be estimated using the following equation:
# ![image.png](attachment:image.png)

# %%
covid_data.loc[4:7,:]
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN         NaN
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
covid_data.interpolate(method='linear').loc[4:7,:] # only applicable to numeric columns
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN  15453024.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
covid_data.duplicated() #Return boolean Series denoting duplicate rows.
# Out:
# Empty DataFrame
# Columns: [country, continent, date, day, month, year, cases, deaths, country_code, population]
# Index: []

# %%
Duplicated

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
   'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
     'rating': [4, 4, 3.5, 15, 5]
 })
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.duplicated(keep='last')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated(keep='first')  #deault keep='first'
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df[df.duplicated(keep='first')]
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0

# %%
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
Remove the duplicated data

# %%
df.drop_duplicates() #Return DataFrame with duplicate rows removed.
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %% [markdown]
# ### 6.Reshaping data:
# - Pandas provides methods for reshaping data, such as pivoting and unstacking.

# %% [markdown]
# ### Tidy data and techniques for restructuring data
# - Tidy data is a term developed by Hadley Wickham. According to a paper authored by him (Link: http://vita.had.co.nz/papers/tidy-data.pdf), these are the three principles of tidy data:
# - 1. Columns correspond to variables in the data, and each variable maps to a single column.
# - 2. The rows contain only observations, not variables.
# - 3. Each data structure or table contains only one observational unit.
# - Note that making data tidy is different from data cleansing.
# - Data cleansing is concerned with dealing with missing values and redundant information, removing filler characters, and changing inaccurate data types.
# - On the other hand, converting data to a tidy format involves restructuring the data and arranging it along the right axis, to facilitate ease of analysis.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Wider

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Longer

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
grades=pd.DataFrame({'Biology':[90,87,45],'Chemistry':[46,56,87],'Mathematics':[95,74,45],'Physics':[75,65,33]},index=['Andrew','Sarah','Jason'])
grades
# Out:
#         Biology  Chemistry  Mathematics  Physics
# Andrew       90         46           95       75
# Sarah        87         56           74       65
# Jason        45         87           45       33

# %%
grades_longer=grades.stack().reset_index()  #wider

# %%
grades_longer.columns=['std_name',"subject",'Marks']

# %%
grades_longer
# Out:
#    std_name      subject  Marks
# 0    Andrew      Biology     90
# 1    Andrew    Chemistry     46
# 2    Andrew  Mathematics     95
# 3    Andrew      Physics     75
# 4     Sarah      Biology     87
# 5     Sarah    Chemistry     56
# 6     Sarah  Mathematics     74
# 7     Sarah      Physics     65
# 8     Jason      Biology     45
# 9     Jason    Chemistry     87
# 10    Jason  Mathematics     45
# 11    Jason      Physics     33

# %%
grades_longer[grades_longer.Marks>45]
# Out:
#   std_name      subject  Marks
# 0   Andrew      Biology     90
# 1   Andrew    Chemistry     46
# 2   Andrew  Mathematics     95
# 3   Andrew      Physics     75
# 4    Sarah      Biology     87
# 5    Sarah    Chemistry     56
# 6    Sarah  Mathematics     74
# 7    Sarah      Physics     65
# 9    Jason    Chemistry     87

# %%
grades=pd.DataFrame({'Student_Name':['Andrew','Sarah','Jason'],'Biology':[90,87,45],
                     'Chemistry':[46,56,87],'Mathematics':[95,74,45],'Physics':[75,65,33]})
grades
# Out:
#   Student_Name  Biology  Chemistry  Mathematics  Physics
# 0       Andrew       90         46           95       75
# 1        Sarah       87         56           74       65
# 2        Jason       45         87           45       33

# %%
grade_longer=grades.melt(id_vars='Student_Name',value_vars=['Biology','Chemistry','Mathematics','Physics'],var_name="Subject",value_name="marks")

# %%
grade_longer
# Out:
#    Student_Name      Subject  marks
# 0        Andrew      Biology     90
# 1         Sarah      Biology     87
# 2         Jason      Biology     45
# 3        Andrew    Chemistry     46
# 4         Sarah    Chemistry     56
# 5         Jason    Chemistry     87
# 6        Andrew  Mathematics     95
# 7         Sarah  Mathematics     74
# 8         Jason  Mathematics     45
# 9        Andrew      Physics     75
# 10        Sarah      Physics     65
# 11        Jason      Physics     33

# %%
grade_longer.pivot_table(values='marks',columns='Subject', index='Student_Name')  # wider
# Out:
# Subject       Biology  Chemistry  Mathematics  Physics
# Student_Name
# Andrew             90         46           95       75
# Jason              45         87           45       33
# Sarah              87         56           74       65

# %% [markdown]
# ### 8.Transforming data:
# - Pandas provides methods for transforming data, such as applying functions or scaling values.

# %%
import pandas as pd 
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv"
olympics=pd.read_csv(url,skiprows=4)
olympics.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
olympics.Gender.unique()
# Out:
# array(['Men', 'Women'], dtype=object)

# %%
olympics.Gender.map({'Men':1,'Women':0})
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 29211    1
# 29212    1
# 29213    1
# 29214    1
# 29215    1
# Name: Gender, Length: 29216, dtype: int64

# %%
olympics.Gender=olympics.Gender.map({'Men':1,'Women':0})

# %%
olympics.Gender=olympics.Gender.apply(lambda x: 1 if x=='Men' else 0)

# %%
olympics.Gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
olympics.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC  Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN       1
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT       1
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE       1
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE       1
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE       1
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
olympics.T
# Out:
#                        0                 1                           2      \
# City                  Athens            Athens                      Athens
# Edition                 1896              1896                        1896
# Sport               Aquatics          Aquatics                    Aquatics
# Discipline          Swimming          Swimming                    Swimming
# Athlete        HAJOS, Alfred  HERSCHMANN, Otto           DRIVAS, Dimitrios
# NOC                      HUN               AUT                         GRE
# Gender                   Men               Men                         Men
# Event         100m freestyle    100m freestyle  100m freestyle for sailors
# Event_gender               M                 M                           M
# Medal                   Gold            Silver                      Bronze
#
#                                    3                           4      \
# City                              Athens                      Athens
# ...

# %% [markdown]
# ### 9.Calculating statistics:
# - Pandas provides methods for calculating various statistics, such as mean, median, standard deviation, and more.

# %% [markdown]
# # Descriptive Statistics

# %%
#Descriptive Statistics/Summarized Statistics of Data Frame
import numpy as np
import pandas as pd
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/subset-covid-data.csv"
covid_data=pd.read_csv(url)
covid_data.head(3)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       206 non-null    object
#  1   continent     206 non-null    object
#  2   date          206 non-null    object
#  3   day           206 non-null    int64
#  4   month         206 non-null    int64
#  5   year          206 non-null    int64
#  6   cases         206 non-null    int64
#  7   deaths        206 non-null    int64
#  8   country_code  202 non-null    object
#  9   population    202 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 16.2+ KB

# %%
covid_data.continent=covid_data.continent.astype('category')

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       206 non-null    object
#  1   continent     206 non-null    category
#  2   date          206 non-null    object
#  3   day           206 non-null    int64
#  4   month         206 non-null    int64
#  5   year          206 non-null    int64
#  6   cases         206 non-null    int64
#  7   deaths        206 non-null    int64
#  8   country_code  202 non-null    object
#  9   population    202 non-null    float64
# dtypes: category(1), float64(1), int64(5), object(3)
# memory usage: 15.0+ KB

# %%
covid_data.continent
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3       Europe
# 4       Africa
#         ...
# 201    America
# 202       Asia
# 203       Asia
# 204     Africa
# 205     Africa
# Name: continent, Length: 206, dtype: category
# Categories (6, object): ['Africa', 'America', 'Asia', 'Europe', 'Oceania', 'Other']

# %%
covid_data.describe( )
#Generate descriptive statistics.
#Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset's distribution,
#excluding ``NaN`` values.
# Out:
#               day       month    year         cases       deaths    population
# count  206.000000  206.000000   206.0    206.000000   206.000000  2.020000e+02
# mean    12.024272    3.985437  2020.0    395.247573    29.713592  3.731716e+07
# std      0.424141    0.209020     0.0   2160.176439   159.533131  1.413776e+08
# min     11.000000    1.000000  2020.0      0.000000     0.000000  1.000000e+03
# 25%     12.000000    4.000000  2020.0      0.000000     0.000000  1.278222e+06
# 50%     12.000000    4.000000  2020.0     11.500000     0.000000  7.042862e+06
# 75%     12.000000    4.000000  2020.0     88.750000     3.000000  2.600084e+07
# max     18.000000    4.000000  2020.0  28391.000000  1831.000000  1.392730e+09

# %%
covid_data.describe( include='all')
# Out:
#             country continent        date         day       month    year  \
# count           206       206         206  206.000000  206.000000   206.0
# unique          206         6           3         NaN         NaN     NaN
# top     Afghanistan    Europe  2020-04-12         NaN         NaN     NaN
# freq              1        54         204         NaN         NaN     NaN
# mean            NaN       NaN         NaN   12.024272    3.985437  2020.0
# std             NaN       NaN         NaN    0.424141    0.209020     0.0
# min             NaN       NaN         NaN   11.000000    1.000000  2020.0
# 25%             NaN       NaN         NaN   12.000000    4.000000  2020.0
# 50%             NaN       NaN         NaN   12.000000    4.000000  2020.0
# 75%             NaN       NaN         NaN   12.000000    4.000000  2020.0
# max             NaN       NaN         NaN   18.000000    4.000000  2020.0
#
#                cases       deaths country_code    population
# ...

# %%
covid_data.describe( include='object')
# Out:
#             country continent        date country_code
# count           206       206         206          202
# unique          206         6           3          202
# top     Afghanistan    Europe  2020-04-12          AFG
# freq              1        54         204            1

# %%
covid_data.describe( include='number')
# Out:
#               day       month    year         cases       deaths    population
# count  206.000000  206.000000   206.0    206.000000   206.000000  2.020000e+02
# mean    12.024272    3.985437  2020.0    395.247573    29.713592  3.731716e+07
# std      0.424141    0.209020     0.0   2160.176439   159.533131  1.413776e+08
# min     11.000000    1.000000  2020.0      0.000000     0.000000  1.000000e+03
# 25%     12.000000    4.000000  2020.0      0.000000     0.000000  1.278222e+06
# 50%     12.000000    4.000000  2020.0     11.500000     0.000000  7.042862e+06
# 75%     12.000000    4.000000  2020.0     88.750000     3.000000  2.600084e+07
# max     18.000000    4.000000  2020.0  28391.000000  1831.000000  1.392730e+09

# %%
covid_data.describe( include='category')
# Out:
#        continent
# count        206
# unique         6
# top       Europe
# freq          54

# %%
#mean
covid_data.mean(numeric_only=True) #Return the mean of the values over the requested axis.
# Out:
# day           1.202427e+01
# month         3.985437e+00
# year          2.020000e+03
# cases         3.952476e+02
# deaths        2.971359e+01
# population    3.731716e+07
# dtype: float64

# %%
covid_data.cases.mean()
# Out:
# 395.247572815534

# %%
covid_data['cases'].mean()
# Out:
# 395.247572815534

# %%
covid_data.median(numeric_only=True)
# Out:
# day                12.0
# month               4.0
# year             2020.0
# cases              11.5
# deaths              0.0
# population    7042861.5
# dtype: float64

# %%
covid_data.cases.median()
# Out:
# 11.5

# %%
covid_data.continent.mode()
# Out:
# 0    Europe
# Name: continent, dtype: category
# Categories (6, object): ['Africa', 'America', 'Asia', 'Europe', 'Oceania', 'Other']

# %%
#Disperson
covid_data.std(numeric_only=True) #Return sample standard deviation over requested axis.
#Normalized by N-1 by default. This can be changed using the ddof argument.
# Out:
# day           4.241413e-01
# month         2.090199e-01
# year          2.279276e-13
# cases         2.160176e+03
# deaths        1.595331e+02
# population    1.413776e+08
# dtype: float64

# %%
covid_data.std(numeric_only=True,ddof=0) # population standard deviation
# Out:
# day           4.231105e-01
# month         2.085120e-01
# year          2.273737e-13
# cases         2.154927e+03
# deaths        1.591454e+02
# population    1.410272e+08
# dtype: float64

# %%
covid_data.var(numeric_only=True) #sample variance over requested axis
#Return unbiased variance over requested axis.
#Normalized by N-1 by default. This can be changed using the ddof argument.
# Out:
# day           1.798958e-01
# month         4.368932e-02
# year          5.195098e-26
# cases         4.666362e+06
# deaths        2.545082e+04
# population    1.998762e+16
# dtype: float64

# %%
covid_data.var(numeric_only=True,ddof=0)#Population variance
# Out:
# day           1.790225e-01
# month         4.347724e-02
# year          5.169879e-26
# cases         4.643710e+06
# deaths        2.532727e+04
# population    1.988867e+16
# dtype: float64

# %%
#correlation
covid_data.corr() #Compute pairwise correlation of columns, excluding NA/null values.
# Out:
#                  day     month  year     cases    deaths  population
# day         1.000000 -0.986416   NaN -0.034746 -0.054326   -0.019167
# month      -0.986416  1.000000   NaN  0.012810  0.013040    0.018663
# year             NaN       NaN   NaN       NaN       NaN         NaN
# cases      -0.034746  0.012810   NaN  1.000000  0.943220    0.175539
# deaths     -0.054326  0.013040   NaN  0.943220  1.000000    0.145211
# population -0.019167  0.018663   NaN  0.175539  0.145211    1.000000

# %%
covid_data.cov()#Compute pairwise covariance of columns, excluding NA/null values.
# Out:
#                      day          month  year         cases        deaths  \
# day         1.798958e-01      -0.087450   0.0 -3.183531e+01 -3.675941e+00
# month      -8.744968e-02       0.043689   0.0  5.784111e+00  4.348331e-01
# year        0.000000e+00       0.000000   0.0  0.000000e+00  0.000000e+00
# cases      -3.183531e+01       5.784111   0.0  4.666362e+06  3.250523e+05
# deaths     -3.675941e+00       0.434833   0.0  3.250523e+05  2.545082e+04
# population -1.160655e+06  556927.821930   0.0  5.412254e+10  3.306423e+09
#
#               population
# day        -1.160655e+06
# month       5.569278e+05
# year        0.000000e+00
# cases       5.412254e+10
# deaths      3.306423e+09
# population  1.998762e+16

# %%
covid_data.skew(numeric_only=True)#Return unbiased skew over requested axis. Normalized by N-1.
# Out:
# day           13.706469
# month        -14.352700
# year           0.000000
# cases         11.147011
# deaths         8.512769
# population     8.566707
# dtype: float64

# %%
covid_data.month.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
covid_data.quantile(q=0.75) #Return values at the given quantile over requested axis.
# Out:
# day                 12.00
# month                4.00
# year              2020.00
# cases               88.75
# deaths               3.00
# population    26000835.25
# Name: 0.75, dtype: float64

# %% [markdown]
# Problem Solving
# 2.Concatenate each month sale Data (https://github.com/svkarthik86/Assignment/tree/main/Sales_Data) into one dataframe and save the dataframe to annual_sale.csv

# %%
months=['January','February','March','April','May','June','July','August','September','October','November','December']

# %%
urls=[f'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_{month}_2019.csv' for month in months]
urls
# Out:
# ['https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv',
#  'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_February_2019.csv',
#  'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_March_2019.csv',
#  'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_April_2019.csv',
#  'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_May_2019.csv',
#  'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_June_2019.csv',
#  'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_July_2019.csv',
#  'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_August_2019.csv',
#  'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_September_2019.csv',
# ...

# %%
all_sales_data=pd.concat([pd.read_csv(url) for url in urls],ignore_index=True)

# %%
all_sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
all_sales_data.isna().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
all_sales_data[all_sales_data.isna().any(axis=1)]
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 664         NaN     NaN              NaN        NaN        NaN
# 678         NaN     NaN              NaN        NaN        NaN
# 797         NaN     NaN              NaN        NaN        NaN
# 876         NaN     NaN              NaN        NaN        NaN
# 1299        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 184678      NaN     NaN              NaN        NaN        NaN
# 184695      NaN     NaN              NaN        NaN        NaN
# 185042      NaN     NaN              NaN        NaN        NaN
# 185729      NaN     NaN              NaN        NaN        NaN
# 186463      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 664                 NaN
# 678                 NaN
# 797                 NaN
# 876                 NaN
# 1299                NaN
# ...                 ...
# 184678              NaN
# ...

# %%
all_sales_data.dropna(how='all',inplace=True)

# %%
all_sales_data.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
# find duplicate
all_sales_data[all_sales_data.duplicated()]
# Out:
#         Order ID                Product  Quantity Ordered  Price Each  \
# 875       142071  AA Batteries (4-pack)                 1        3.84
# 1102    Order ID                Product  Quantity Ordered  Price Each
# 1194    Order ID                Product  Quantity Ordered  Price Each
# 1897    Order ID                Product  Quantity Ordered  Price Each
# 2463    Order ID                Product  Quantity Ordered  Price Each
# ...          ...                    ...               ...         ...
# 185070  Order ID                Product  Quantity Ordered  Price Each
# 185085    317971  AA Batteries (4-pack)                 1        3.84
# 185481  Order ID                Product  Quantity Ordered  Price Each
# 185925  Order ID                Product  Quantity Ordered  Price Each
# 185955  Order ID                Product  Quantity Ordered  Price Each
#
#             Order Date                          Purchase Address
# ...

# %%
all_sales_data.drop_duplicates(inplace=True)

# %%
all_sales_data.duplicated().sum()
# Out:
# 0

# %%
all_sales_data.columns = all_sales_data.columns.str.replace(' ','_')

# %%
all_sales_data.head()
# Out:
#   Order_ID                   Product Quantity_Ordered Price_Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order_Date                       Purchase_Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
all_sales_data.Price_Each.astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 all_sales_data.Price_Each.astype('float')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
all_sales_data=all_sales_data[~(all_sales_data.Price_Each=='Price Each')]

# %%
all_sales_data.Price_Each=all_sales_data.Price_Each.astype('float')
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_22044\296709216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sales_data.Price_Each=all_sales_data.Price_Each.astype('float')

# %%
all_sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity_Ordered  185686 non-null  object
#  3   Price_Each        185686 non-null  float64
#  4   Order_Date        185686 non-null  object
#  5   Purchase_Address  185686 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 9.9+ MB

# %%
all_sales_data.Product.value_counts()
# Out:
# USB-C Charging Cable          21859
# Lightning Charging Cable      21610
# AAA Batteries (4-pack)        20612
# AA Batteries (4-pack)         20558
# Wired Headphones              18849
# Apple Airpods Headphones      15525
# Bose SoundSport Headphones    13298
# 27in FHD Monitor               7498
# iPhone                         6840
# 27in 4K Gaming Monitor         6225
# 34in Ultrawide Monitor         6174
# Google Phone                   5522
# Flatscreen TV                  4794
# Macbook Pro Laptop             4721
# ThinkPad Laptop                4126
# 20in Monitor                   4098
# Vareebadd Phone                2065
# LG Washing Machine              666
# LG Dryer                        646
# Name: Product, dtype: int64

# %%
plt.figure(figsize=(8,6))
all_sales_data.Product.value_counts().plot(kind='bar',color='green')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Data Visualization

# %%
### matplotlib installation

# %%
# !pip install matplotlib

# %%
import matplotlib#.pyplot as plt

# %%
matplotlib.__version__
# Out:
# '3.5.1'

# %%
import matplotlib.pyplot as plt

# %%
#attribute and methods  of plt object
print(dir(plt))
# Out:
# ['Annotation', 'Arrow', 'Artist', 'AutoLocator', 'Axes', 'Button', 'Circle', 'Figure', 'FigureCanvasBase', 'FixedFormatter', 'FixedLocator', 'FormatStrFormatter', 'Formatter', 'FuncFormatter', 'GridSpec', 'IndexLocator', 'Line2D', 'LinearLocator', 'Locator', 'LogFormatter', 'LogFormatterExponent', 'LogFormatterMathtext', 'LogLocator', 'MaxNLocator', 'MouseButton', 'MultipleLocator', 'Normalize', 'NullFormatter', 'NullLocator', 'Number', 'PolarAxes', 'Polygon', 'Rectangle', 'ScalarFormatter', 'Slider', 'Subplot', 'SubplotSpec', 'Text', 'TickHelper', 'Widget', '_INSTALL_FIG_OBSERVER', '_IP_REGISTERED', '_IoffContext', '_IonContext', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_api', '_auto_draw_if_interactive', '_backend_mod', '_copy_docstring_and_deprecators', '_get_required_interactive_framework', '_interactive_bk', '_log', '_pylab_helpers', '_setup_pyplot_info_docstrings', '_warn_if_gui_out_of_main_thread', '_xkcd', 'aco
# ...

# %%
plt.plot([2,14,6,8]) #Plot y versus x as lines and/or markers.
plt.show()

# %%
plt.figure(figsize=(8,6),facecolor='pink',edgecolor='y')
plt.plot([2,14,6,8],marker='o',c='g',linestyle='dashed',label='data') #Plot y versus x as lines and/or markers.
plt.plot([10,3,15,6])
plt.sin()
plt.legend()
plt.grid()
plt.title('this is Demo Plot')
plt.xlabel('x-axis label')
plt.ylabel('y-axis label')
plt.show()

# %%
np.linspace(0, 2*np.pi, 100)
# Out:
# array([0.        , 0.06346652, 0.12693304, 0.19039955, 0.25386607,
#        0.31733259, 0.38079911, 0.44426563, 0.50773215, 0.57119866,
#        0.63466518, 0.6981317 , 0.76159822, 0.82506474, 0.88853126,
#        0.95199777, 1.01546429, 1.07893081, 1.14239733, 1.20586385,
#        1.26933037, 1.33279688, 1.3962634 , 1.45972992, 1.52319644,
#        1.58666296, 1.65012947, 1.71359599, 1.77706251, 1.84052903,
#        1.90399555, 1.96746207, 2.03092858, 2.0943951 , 2.15786162,
#        2.22132814, 2.28479466, 2.34826118, 2.41172769, 2.47519421,
#        2.53866073, 2.60212725, 2.66559377, 2.72906028, 2.7925268 ,
#        2.85599332, 2.91945984, 2.98292636, 3.04639288, 3.10985939,
#        3.17332591, 3.23679243, 3.30025895, 3.36372547, 3.42719199,
#        3.4906585 , 3.55412502, 3.61759154, 3.68105806, 3.74452458,
#        3.8079911 , 3.87145761, 3.93492413, 3.99839065, 4.06185717,
#        4.12532369, 4.1887902 , 4.25225672, 4.31572324, 4.37918976,
# ...

# %%
import numpy as np

import matplotlib.pyplot as plt
X = np.linspace(0, 2*np.pi, 100)
Y = np.cos(X)
Y1=np.sin(X)
fig, ax = plt.subplots(2,2)
ax[1][1].plot(X, Y, color='green')
ax[0][0].plot(X, Y1, color='red')
fig.savefig('figure.pdf')
fig.show()
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_22044\1843486182.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
product=all_sales_data.Product.value_counts()
product
# Out:
# USB-C Charging Cable          21859
# Lightning Charging Cable      21610
# AAA Batteries (4-pack)        20612
# AA Batteries (4-pack)         20558
# Wired Headphones              18849
# Apple Airpods Headphones      15525
# Bose SoundSport Headphones    13298
# 27in FHD Monitor               7498
# iPhone                         6840
# 27in 4K Gaming Monitor         6225
# 34in Ultrawide Monitor         6174
# Google Phone                   5522
# Flatscreen TV                  4794
# Macbook Pro Laptop             4721
# ThinkPad Laptop                4126
# 20in Monitor                   4098
# Vareebadd Phone                2065
# LG Washing Machine              666
# LG Dryer                        646
# Name: Product, dtype: int64

# %%
product.values
# Out:
# array([21859, 21610, 20612, 20558, 18849, 15525, 13298,  7498,  6840,
#         6225,  6174,  5522,  4794,  4721,  4126,  4098,  2065,   666,
#          646], dtype=int64)

# %% [markdown]
# plt.figure(figsize=(8,6))
# plt.bar(x=product.index,height=product.values,color='green')
# plt.xticks( rotation=90)
# plt.show()

# %% [markdown]
# # Data Visualization using DataFrame plot()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file='https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/WEEK-9%20Assignment/Data/AMZN_data.csv'
amazon_data=pd.read_csv(file)
amazon_data.head()
# Out:
#          date    open    high      low   close   volume  Name
# 0  2013-02-08  261.40  265.25  260.555  261.95  3879078  AMZN
# 1  2013-02-11  263.20  263.25  256.600  257.21  3403403  AMZN
# 2  2013-02-12  259.19  260.16  257.000  258.70  2938660  AMZN
# 3  2013-02-13  261.53  269.96  260.300  269.47  5292996  AMZN
# 4  2013-02-14  267.37  270.65  265.400  269.24  3462780  AMZN

# %%
import pandas as pd
import matplotlib.pyplot as plt
file='https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/WEEK-9%20Assignment/Data/GOOGL_data.csv'
google_data=pd.read_csv(file)
google_data.head()
# Out:
#          date      open      high       low     close   volume   Name
# 0  2013-02-08  390.4551  393.7283  390.1698  393.0777  6031199  GOOGL
# 1  2013-02-11  389.5892  391.8915  387.2619  391.6012  4330781  GOOGL
# 2  2013-02-12  391.2659  394.3440  390.0747  390.7403  3714176  GOOGL
# 3  2013-02-13  390.4551  393.0677  390.3750  391.8214  2393946  GOOGL
# 4  2013-02-14  390.2549  394.7644  389.2739  394.3039  3466971  GOOGL

# %%
# Line Chart x=date and y=close_price
amazon_data.plot(x='date',y='close',kind='line',rot=90,color='g',title="Amazon")  # defalut kind='line'
google_data.plot(x='date',y='close',kind='line',rot=90,color='red',title='Google')
# Out:
# <AxesSubplot:title={'center':'Google'}, xlabel='date'>

# %%
#bar graph

# %%
import pandas as pd
# Load a sample DataFrame
olympic_df = pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv",skiprows=4)
olympic_df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
olympic_df.Medal.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
olympic_df.Gender.value_counts().plot(kind='barh',color='blue')
# Out:
# <AxesSubplot:>

# %%
#histogram

# %%
google_data.head()
# Out:
#          date      open      high       low     close   volume   Name
# 0  2013-02-08  390.4551  393.7283  390.1698  393.0777  6031199  GOOGL
# 1  2013-02-11  389.5892  391.8915  387.2619  391.6012  4330781  GOOGL
# 2  2013-02-12  391.2659  394.3440  390.0747  390.7403  3714176  GOOGL
# 3  2013-02-13  390.4551  393.0677  390.3750  391.8214  2393946  GOOGL
# 4  2013-02-14  390.2549  394.7644  389.2739  394.3039  3466971  GOOGL

# %%
google_data.plot(x='close',kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
google_data.close.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 'kde' : Kernel Density Estimation plot

# %%
google_data.close.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# - 'density' : same as 'kde'

# %%
google_data.close.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# - 'area' : area plot

# %%
google_data.close.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
#  - 'box' : boxplot

# %%
google_data.close.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
google_data.head(2)
# Out:
#          date      open      high       low     close   volume   Name
# 0  2013-02-08  390.4551  393.7283  390.1698  393.0777  6031199  GOOGL
# 1  2013-02-11  389.5892  391.8915  387.2619  391.6012  4330781  GOOGL

# %%
google_data[['open','close']].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
google_data.volume.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
olympic_df.Gender.value_counts().plot(kind='pie',autopct="%1.2f",explode=[0,0.2])
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
google_data.head(2)
# Out:
#          date      open      high       low     close   volume   Name
# 0  2013-02-08  390.4551  393.7283  390.1698  393.0777  6031199  GOOGL
# 1  2013-02-11  389.5892  391.8915  387.2619  391.6012  4330781  GOOGL

# %%
google_data.plot(x='volume',y='close',kind='scatter')
plt.grid()

# %%
google_data[['volume','close']].corr()
# Out:
#           volume     close
# volume  1.000000 -0.424353
# close  -0.424353  1.000000

# %% [markdown]
# ### Data Visualization using Matlablib and Seaborn lib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
file='https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/WEEK-9%20Assignment/Data/movie_scores.csv'
movie_score=pd.read_csv(file)
movie_score
# Out:
#    Unnamed: 0                         MovieTitle  Tomatometer  AudienceScore
# 0           0                 The Shape of Water           91             73
# 1           1                      Black Panther           97             79
# 2           2                            Dunkirk           92             81
# 3           3                        The Martian           91             91
# 4           4  The Hobbit: An Unexpected Journey           64             83

# %%
#matplot

# %%
plt.bar(movie_score['MovieTitle'],movie_score['Tomatometer'],label='Tomatometer',align='edge')
plt.bar(movie_score['MovieTitle'],movie_score['AudienceScore'],label='Tomatometer')
plt.legend()

# %%
#Longer to wider

# %%
movie_score=movie_score.melt(id_vars='MovieTitle',value_vars=['Tomatometer','AudienceScore'],var_name='Type',value_name='score')
movie_score

# %%
movie_score
# Out:
#                           MovieTitle           Type  score
# 0                 The Shape of Water    Tomatometer     91
# 1                      Black Panther    Tomatometer     97
# 2                            Dunkirk    Tomatometer     92
# 3                        The Martian    Tomatometer     91
# 4  The Hobbit: An Unexpected Journey    Tomatometer     64
# 5                 The Shape of Water  AudienceScore     73
# 6                      Black Panther  AudienceScore     79
# 7                            Dunkirk  AudienceScore     81
# 8                        The Martian  AudienceScore     91
# 9  The Hobbit: An Unexpected Journey  AudienceScore     83

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
movie_score
# Out:
#                           MovieTitle           Type  score
# 0                 The Shape of Water    Tomatometer     91
# 1                      Black Panther    Tomatometer     97
# 2                            Dunkirk    Tomatometer     92
# 3                        The Martian    Tomatometer     91
# 4  The Hobbit: An Unexpected Journey    Tomatometer     64
# 5                 The Shape of Water  AudienceScore     73
# 6                      Black Panther  AudienceScore     79
# 7                            Dunkirk  AudienceScore     81
# 8                        The Martian  AudienceScore     91
# 9  The Hobbit: An Unexpected Journey  AudienceScore     83

# %%
plt.style.use('default')

# %%
plt.figure(figsize=(7,4))
sns.barplot(x='MovieTitle',y='score', hue='Type', data=movie_score)
plt.xticks(rotation=45)
plt.show()

# %%
sns.get_dataset_names() #show the buildin dataset
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris_data=sns.load_dataset('iris')
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
iris_data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.scatterplot(x='petal_length',y='petal_width', data=iris_data,hue='species')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>
