# %%
int("56r")
print("someother program")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 int("56r")
#       2 print("someother program")
#
# ValueError: invalid literal for int() with base 10: '56r'

# %%
try:
    int("56r")
except ValueError:
    print('This is Value Error, Please Check your Value')
print("someother program")
# Out:
# This is Value Error, Please Check your Value
# someother program

# %%
while True:
    try:
        num=input("Enter Your Number: ")
        v1=int(num)
        print("Value converted Successfully")
        break
    except ValueError:
        print('This is Value Error, Please Check your Value')
# Out:
# Enter Your Number: 45o
# This is Value Error, Please Check your Value
# Enter Your Number: 87k
# This is Value Error, Please Check your Value
# Enter Your Number: 90
# Value converted Successfully

# %%
int(input("Enter Your Number1: "))
# Out:
# Enter Your Number1: rk
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 int(input("Enter Your Number1: "))
#
# ValueError: invalid literal for int() with base 10: 'rk'

# %%
try:
    a=int(input("Enter Your Number1: "))
    b=int(input("Enter Your Number2: "))
    c=a/b
    print(c)
except (ValueError,ZeroDivisionError):
    print("Value Error or ZeroDivisionError, Please Check your input Value")
# Out:
# Enter Your Number1: 5646
# Enter Your Number2: gh
# Value Error or ZeroDivisionError, Please Check your input Value

# %%
 ├── ArithmeticError
      │    ├── FloatingPointError
      │    ├── OverflowError
      │    └── ZeroDivisionError

# %%
pow(2.0, 100000000)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 pow(2.0, 100000000)
#
# OverflowError: (34, 'Result too large')

# %%
34.67676878/8980909090
# Out:
# 3.861164658554628e-09

# %%
try:
    
    c=5/0
    
except ArithmeticError:
    print("This is ArithmeticError")
# Out:
# This is ArithmeticError

# %%
The class hierarchy for built-in exceptions is:

BaseException
 ├── BaseExceptionGroup
 ├── GeneratorExit
 ├── KeyboardInterrupt
 ├── SystemExit
 └── Exception
      ├── ArithmeticError
      │    ├── FloatingPointError
      │    ├── OverflowError
      │    └── ZeroDivisionError
      ├── AssertionError
      ├── AttributeError
      ├── BufferError
      ├── EOFError
      ├── ExceptionGroup [BaseExceptionGroup]
      ├── ImportError
      │    └── ModuleNotFoundError
      ├── LookupError
      │    ├── IndexError
      │    └── KeyError
      ├── MemoryError
      ├── NameError
      │    └── UnboundLocalError
      ├── OSError
      │    ├── BlockingIOError
      │    ├── ChildProcessError
      │    ├── ConnectionError
      │    │    ├── BrokenPipeError
      │    │    ├── ConnectionAbortedError
      │    │    ├── ConnectionRefusedError
      │    │    └── ConnectionResetError
      │    ├── FileExistsError
      │    ├── FileNotFoundError
      │    ├── InterruptedError
      │    ├── IsADirectoryError
      │    ├── NotADirectoryError
      │    ├── PermissionError
      │    ├── ProcessLookupError
      │    └── TimeoutError
      ├── ReferenceError
      ├── RuntimeError
      │    ├── NotImplementedError
      │    └── RecursionError
      ├── StopAsyncIteration
      ├── StopIteration
      ├── SyntaxError
      │    └── IndentationError
      │         └── TabError
      ├── SystemError
      ├── TypeError
      ├── ValueError
      │    └── UnicodeError
      │         ├── UnicodeDecodeError
      │         ├── UnicodeEncodeError
      │         └── UnicodeTranslateError
      └── Warning
           ├── BytesWarning
           ├── DeprecationWarning
           ├── EncodingWarning
           ├── FutureWarning
           ├── ImportWarning
           ├── PendingDeprecationWarning
           ├── ResourceWarning
           ├── RuntimeWarning
           ├── SyntaxWarning
           ├── UnicodeWarning
           └── UserWarning

# %% [markdown]
# # try except else
#
# ![image.png](attachment:image.png)

# %%
try:      
    a=10/7;      
except(ArithmeticError, IOError,ValueError,TypeError):      
        print("Arithmetic Exception")      
else:      
    print(a)
    print("Successfully Done")
# Out:
# 1.4285714285714286
# Successfully Done

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example: try, except, else, finally blocks
try:
    x=int(input('Enter a number: '))
    y=int(input('Enter another number: '))
    z=x/y
except(ZeroDivisionError,TypeError,ValueError):
    print("except ZeroDivisionError block or Type mismatch")
    print("Division by 0 not accepted")
else:
    print("else block")
    print("Division = ", z)
finally:
    print("finally block")
    
print ("Out of try, except, else and finally blocks." )
# Out:
# Enter a number: 5
# Enter another number: 0
# except ZeroDivisionError block or Type mismatch
# Division by 0 not accepted
# finally block
# Out of try, except, else and finally blocks.

# %% [markdown]
# # raise exception

# %%
### Example: Raise an Exception
while True:
    try:
        x=int(input('Enter a number upto 100: '))
        if x > 100:
            raise ValueError(x)  # value error exception invoked using raise #explicit 
        break
    except ValueError:
        print(x, "is out of allowed range")
    else:
        print(x, "is within the allowed range")

# %%
Problem Solveing

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
coffee = ["Café Latte", "Caffe Americano", "Espresso", "Cappuccino", "Macchiato"]
choice = int(input())
coffee[choice]

# %%
try:
    coffee = ["Café Latte", "Caffe Americano", "Espresso", "Cappuccino", "Macchiato"]
    choice = int(input())
    print(coffee[choice])

except IndexError:
    print('Invalid number')

finally:
    print('Have a good day')
# Out:
# 8
# Invalid number
# Have a good day

# %%
 coffee[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 coffee[5]
#
# IndexError: list index out of range

# %%
#exception handling
coffee = ["Café Latte", "Caffe Americano", "Espresso", "Cappuccino", "Macchiato"]
try:
   choice = int(input("Enter choice(0/1/2/3/4) : "))
   print(coffee[ch])
except IndexError :
   print("You entered invalid number!")
finally :
   print("Have a good day!")
# Out:
# Enter choice(0/1/2/3/4) : 6
# Have a good day!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [53], in <cell line: 3>()
#       3 try:
#       4    choice = int(input("Enter choice(0/1/2/3/4) : "))
# ----> 5    print(coffee[ch])
#       6 except IndexError :
#       7    print("You entered invalid number!")
#
# NameError: name 'ch' is not defined

# %%
coffee=["cafe Latte","Cafe Americano","Espresso","Cappuccino","Machiato"]
try:
  no=int(input("enter the coffee choice"))
  print(f'your choice is {coffee[no]}')
except IndexError:
  print("please choose from the given menu")
  print(coffee)
finally:
  print("Have a nice day")
# Out:
# enter the coffee choice8
# please choose from the given menu
# ['cafe Latte', 'Cafe Americano', 'Espresso', 'Cappuccino', 'Machiato']
# Have a nice day

# %%
class MyCustomError2(Exception):
    def __init__(self, message):
        self.message = message

# %%
class MyCustomError(Exception):
    def __init__(self, message):
        self.message = message

# %%
def divide(a, b):
    if b == 0:
        raise MyCustomError2("Division by zero is not allowed")
    return a / b

try:
    result = divide(10, 0)
except MyCustomError as e:
    print(e.message)
# Out:
# ---------------------------------------------------------------------------
# MyCustomError2                            Traceback (most recent call last)
# Input In [70], in <cell line: 6>()
#       4     return a / b
#       6 try:
# ----> 7     result = divide(10, 0)
#       8 except MyCustomError as e:
#       9     print(e.message)
#
# Input In [70], in divide(a, b)
#       1 def divide(a, b):
#       2     if b == 0:
# ----> 3         raise MyCustomError2("Division by zero is not allowed")
#       4     return a / b
#
# MyCustomError2: Division by zero is not allowed
